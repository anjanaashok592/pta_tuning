# %%
import pickle, copy, json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as ticker
import matplotlib as mpl
import matplotlib.cm as cm
import scipy.stats as sps
from random import shuffle
import itertools

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
#import la_forge.utils as lf_utils
#lf_utils.set_publication_params({'text.usetex':False})
#fig_dir = '/home/baierj/projects/hasasia2/hasasia2_paper/figures'

# %%
import healpy as hp
import astropy.units as u
import astropy.constants as c
from astropy.coordinates import SkyCoord
#import plot #Script originally written by Leo Stein for making pretty sky maps. 

# Setting various healpy quantities and GW source sky positions.
NSIDE = 8
NPIX = hp.nside2npix(NSIDE)
IPIX = np.arange(NPIX)
theta_gw, phi_gw = hp.pix2ang(nside=NSIDE,ipix=IPIX)

# %%
import numpy as np
import scipy.linalg as sl
import matplotlib.pyplot as plt
# %matplotlib inline
import glob, pickle, json
import hasasia.sensitivity as hsen
import hasasia.sim as hsim
import hasasia.skymap as hsky
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
mpl.rcParams['figure.figsize'] = [5,3]
mpl.rcParams['text.usetex'] = True
from enterprise.pulsar import Pulsar as ePulsar
# Out:
# /opt/homebrew/Caskroom/mambaforge/base/envs/sarahspta/lib/python3.12/site-packages/enterprise/signals/utils.py:13: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import Requirement, resource_filename
# libstempo not installed. PINT or libstempo are required to use par and tim files.
# RuntimeWarning: This platform does not support extended precision floating-point, and PINT will run at reduced precision.

# %%
#get Sarah's data
ng20_irn = '/Users/ashokan/osu/sarahspta/NG20_irn/'
pardir = ng20_irn
timdir = ng20_irn
pars = sorted(glob.glob(pardir+'*.par'))
tims = sorted(glob.glob(timdir+'*.tim'))

# %%
#check number of pulsars
print(len(pars))
print(len(tims))
# Out:
# 77
# 77

# %%
#check first par and tim files
print(pars[0])
print(tims[0])
# Out:
# /Users/ashokan/osu/sarahspta/NG20_irn/B1855+09.par
# /Users/ashokan/osu/sarahspta/NG20_irn/B1855+09.tim

# %%
#make enterprise pulsars
ePsrs = []
for par,tim in zip(pars,tims):
    ePsr = ePulsar(par, tim,  ephem='DE440')
    ePsrs.append(ePsr)
    print('\rPSR {0} complete'.format(ePsr.name),end='',flush=True)
# Out:
# 2025-10-06 22:20:56.122 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2021 from the given model
# 2025-10-06 22:20:56.473 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-06 22:20:56.478 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-06 22:20:56.486 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:20:56.487 | DEBUG    | pint.observatory:_load_gps_clock:108 - Loading global GPS clock file
# 2025-10-06 22:20:56.735 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file gps2utc.clk saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-10-06 22:20:56.840 | DEBUG    | pint.observatory.clock_file:read_tempo2_clock_file:463 - Loading TEMPO2-format observatory clock correction file gps2utc.clk (/Users/ashokan/.astropy/cache/download/url/d3c81b5766f4bfb84e65504c8a453085/contents) with bogus_last_correction=False
# 2025-10-06 22:20:56.860 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for gps2utc.clk with bogus_last_correction=False
# 2025-10-06 22:20:56.861 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-06 22:20:56.861 | INFO     | pint.observatory:_load_bipm_clock:119 - Loading BIPM clock version bipm2021
# 2025-10-06 22:20:56.864 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file tai2tt_bipm2021.clk saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-10-06 22:20:56.896 | DEBUG    | pint.observatory.clock_file:read_tempo2_clock_file:463 - Loading TEMPO2-format observatory clock correction file tai2tt_bipm2021.clk (/Users/ashokan/.astropy/cache/download/url/e00edeef4edde217d65207a9abeb6a8c/contents) with bogus_last_correction=False
# 2025-10-06 22:20:56.900 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for tai2tt_bipm2021.clk with bogus_last_correction=False
# 2025-10-06 22:20:56.901 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file time_ao.dat saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-10-06 22:20:56.912 | DEBUG    | pint.observatory.clock_file:read_tempo_clock_file:613 - Loading TEMPO-format observatory clock correction file time_ao.dat (/Users/ashokan/.astropy/cache/download/url/36fe8d7a16ab23eeb27a998de5b7eea4/contents) with bogus_last_correction=False
# 2025-10-06 22:20:56.923 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for time_ao.dat with bogus_last_correction=False
# 2025-10-06 22:20:56.924 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-06 22:20:56.995 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:20:56.996 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# UserWarning: Data points out of range in clock file 'tai2tt_bipm2021.clk'
# 2025-10-06 22:20:56.998 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-06 22:20:57.104 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:20:57.105 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-06 22:20:57.107 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file time_gbt.dat saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-10-06 22:20:57.115 | DEBUG    | pint.observatory.clock_file:read_tempo_clock_file:613 - Loading TEMPO-format observatory clock correction file time_gbt.dat (/Users/ashokan/.astropy/cache/download/url/599e3ebbfc317e090244ee1ef4c79374/contents) with bogus_last_correction=False
# 2025-10-06 22:20:57.116 | INFO     | pint.observatory.clock_file:read_tempo_clock_file:703 - Disregarding suspicious MJD -2271.5 in TEMPO clock file
# 2025-10-06 22:20:57.129 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for time_gbt.dat with bogus_last_correction=False
# 2025-10-06 22:20:57.130 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='gbt'.
# 2025-10-06 22:20:57.139 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-06 22:20:57.139 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-06 22:20:57.188 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-06 22:20:57.189 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-06 22:20:57.259 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.713 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [5.39316141e+09 1.34911428e+11 5.84771576e+10] m
# 2025-10-06 22:20:57.714 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.716 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.718 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.719 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.720 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.721 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.722 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.732 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.764 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-7.93797492e+09 -1.38231720e+11 -5.99234428e+10] m
# 2025-10-06 22:20:57.766 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.767 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.768 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.770 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.772 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.773 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.774 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.776 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.780 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.48209377e+11  2.02008500e+10  8.78368581e+09] m
# 2025-10-06 22:20:57.781 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.781 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.781 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.782 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.782 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.783 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.783 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.784 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-06 22:20:57.840 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.869 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.903 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:57.908 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-06 22:20:57.910 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:57.920 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:57.962 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:57.964 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:57.975 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-10-06 22:20:57.976 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-06 22:20:57.977 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-06 22:20:57.978 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:20:57.978 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-06 22:20:57.979 | INFO     | pint.observatory:_load_bipm_clock:119 - Loading BIPM clock version bipm2023
# 2025-10-06 22:20:57.981 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file tai2tt_bipm2023.clk saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-10-06 22:20:58.016 | DEBUG    | pint.observatory.clock_file:read_tempo2_clock_file:463 - Loading TEMPO2-format observatory clock correction file tai2tt_bipm2023.clk (/Users/ashokan/.astropy/cache/download/url/d0c6b0f6a57e39d4a167cd2aa08ad383/contents) with bogus_last_correction=False
# 2025-10-06 22:20:58.020 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for tai2tt_bipm2023.clk with bogus_last_correction=False
# 2025-10-06 22:20:58.021 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-06 22:20:58.022 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-06 22:20:58.023 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-06 22:20:58.024 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-06 22:20:58.025 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:58.030 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.49328670e+11  6.35100491e+09  2.76121816e+09] m
# 2025-10-06 22:20:58.030 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:58.031 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:58.032 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:58.033 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:58.034 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:58.034 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:58.035 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:58.036 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-06 22:20:58.037 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-06 22:20:58.073 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:58.079 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-06 22:20:58.080 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.081 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.139 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.140 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.171 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.173 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.219 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.222 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.265 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.266 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.308 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.309 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.351 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.353 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.404 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.405 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.448 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.454 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.499 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.501 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.543 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.545 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.593 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.594 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.612 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.660 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:58.665 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR B1855+09 complete
# 2025-10-06 22:20:58.759 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2021 from the given model
# 2025-10-06 22:20:58.954 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-06 22:20:58.956 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-06 22:20:58.963 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:20:58.964 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-06 22:20:58.966 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-06 22:20:59.011 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:20:59.012 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# UserWarning: Data points out of range in clock file 'tai2tt_bipm2021.clk'
# 2025-10-06 22:20:59.017 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-06 22:20:59.077 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-06 22:20:59.078 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-06 22:20:59.106 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-06 22:20:59.107 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-06 22:20:59.110 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.123 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 6.39615815e+10 -1.26375641e+11 -5.47812334e+10] m
# 2025-10-06 22:20:59.124 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.125 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.126 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.127 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.128 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.130 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.131 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.138 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.170 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.19388263e+11 -8.35025455e+10 -3.61964919e+10] m
# 2025-10-06 22:20:59.171 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.172 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.173 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.174 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.176 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.178 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.179 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.181 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-06 22:20:59.220 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.237 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.259 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-06 22:20:59.259 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.261 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.293 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.294 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.303 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-10-06 22:20:59.304 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-06 22:20:59.305 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-06 22:20:59.305 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:20:59.306 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-06 22:20:59.306 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-06 22:20:59.308 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-06 22:20:59.308 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-06 22:20:59.309 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-06 22:20:59.311 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.314 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 4.17618730e+10 -1.34483104e+11 -5.83157546e+10] m
# 2025-10-06 22:20:59.315 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.316 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.316 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.317 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.318 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.319 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.320 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.321 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-06 22:20:59.322 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-06 22:20:59.348 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:20:59.351 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-06 22:20:59.352 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.352 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.415 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.417 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.466 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.468 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.528 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.530 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.590 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.594 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.649 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.650 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.702 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.704 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.756 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.758 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.811 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.813 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.859 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.862 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.907 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.908 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.967 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:20:59.968 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.026 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.029 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.047 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.080 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.081 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR B1953+29 complete
# 2025-10-06 22:21:00.137 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2021 from the given model
# 2025-10-06 22:21:00.276 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-06 22:21:00.283 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-06 22:21:00.289 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:21:00.289 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-06 22:21:00.290 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-06 22:21:00.336 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:21:00.338 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# UserWarning: Data points out of range in clock file 'tai2tt_bipm2021.clk'
# 2025-10-06 22:21:00.340 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-06 22:21:00.486 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:21:00.487 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-06 22:21:00.490 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='gbt'.
# 2025-10-06 22:21:00.495 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-06 22:21:00.496 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-06 22:21:00.557 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-06 22:21:00.558 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-06 22:21:00.562 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.576 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.42573928e+11  3.86926049e+10  1.67754082e+10] m
# 2025-10-06 22:21:00.577 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.578 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.581 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.582 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.583 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.584 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.584 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.593 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.630 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 1.08241462e+11 -9.60944106e+10 -4.16553595e+10] m
# 2025-10-06 22:21:00.631 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.634 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.635 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.637 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.639 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.640 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.642 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.644 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.648 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.49334981e+11  1.22473747e+10  5.33256030e+09] m
# 2025-10-06 22:21:00.649 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.650 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.651 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.651 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.652 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.654 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.655 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.656 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-06 22:21:00.694 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.721 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.759 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.763 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-06 22:21:00.765 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.767 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.793 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.795 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.810 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-10-06 22:21:00.811 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-06 22:21:00.812 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-06 22:21:00.813 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:21:00.814 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-06 22:21:00.815 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-06 22:21:00.816 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-06 22:21:00.816 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-06 22:21:00.817 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-06 22:21:00.818 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.820 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 5.87710243e+10 -1.29005528e+11 -5.59435250e+10] m
# 2025-10-06 22:21:00.821 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.823 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.824 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.825 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.826 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.826 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.827 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.828 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-06 22:21:00.829 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-06 22:21:00.853 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:00.857 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-06 22:21:00.858 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.858 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.904 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.906 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.949 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:00.950 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.000 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.003 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.054 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.055 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.111 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.117 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.185 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.187 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.245 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.256 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.309 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.311 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.357 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.365 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.430 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.433 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.492 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.493 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.548 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.550 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.618 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.621 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.681 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.683 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.735 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.737 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.788 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.790 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.813 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# WARNING: Could not find pulsar distance for PSR J0023+0923. Setting value to 1 with 20% uncertainty.
# 2025-10-06 22:21:01.845 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:21:01.847 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR J0023+0923 complete
# 2025-10-06 22:21:01.888 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2021 from the given model
# 2025-10-06 22:21:02.037 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-06 22:21:02.040 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-06 22:21:02.056 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:21:02.057 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-06 22:21:02.058 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-06 22:21:02.237 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:21:02.237 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# UserWarning: Data points out of range in clock file 'tai2tt_bipm2021.clk'
# 2025-10-06 22:21:02.240 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-06 22:21:02.337 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:21:02.338 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-06 22:21:02.340 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='gbt'.
# 2025-10-06 22:21:02.347 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-06 22:21:02.348 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-06 22:21:02.410 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-06 22:21:02.410 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-06 22:21:02.418 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.453 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-8.36297648e+10  1.10796443e+11  4.80187109e+10] m
# 2025-10-06 22:21:02.454 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.455 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.456 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.457 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.458 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.458 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.459 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.467 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.499 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 1.08643378e+11 -9.57127228e+10 -4.14874860e+10] m
# 2025-10-06 22:21:02.500 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.502 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.503 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.504 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.505 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.506 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.507 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.508 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.513 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.49340830e+11  1.21982273e+10  5.31103108e+09] m
# 2025-10-06 22:21:02.514 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.514 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:21:02.515 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# ...
# 2025-10-06 22:22:26.062 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-06 22:22:26.087 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:26.090 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-06 22:22:26.091 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.092 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.141 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.143 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.178 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.181 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.227 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.229 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.280 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.282 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.325 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.327 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.371 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.373 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.416 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.419 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.463 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.465 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.507 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.509 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.555 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.560 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.604 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.606 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.665 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.667 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.690 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.724 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:26.725 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR J2317+1439 complete
# 2025-10-06 22:22:26.815 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2021 from the given model
# 2025-10-06 22:22:26.885 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-06 22:22:26.887 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-06 22:22:26.891 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:22:26.892 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-06 22:22:26.892 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-06 22:22:26.918 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:22:26.919 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# UserWarning: Data points out of range in clock file 'tai2tt_bipm2021.clk'
# 2025-10-06 22:22:26.922 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-06 22:22:26.973 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:22:26.974 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-06 22:22:26.976 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='gbt'.
# 2025-10-06 22:22:26.982 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-06 22:22:26.982 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-06 22:22:27.007 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-06 22:22:27.007 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-06 22:22:27.009 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.019 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.32090790e+11  6.03101032e+10  2.61245816e+10] m
# 2025-10-06 22:22:27.019 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.020 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.020 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.021 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.022 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.022 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.023 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.027 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.045 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.18404074e+11 -8.46988267e+10 -3.67168762e+10] m
# 2025-10-06 22:22:27.045 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.046 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.048 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.050 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.052 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.053 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.055 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.059 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.063 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.47905662e+11  2.18445975e+10  9.49398036e+09] m
# 2025-10-06 22:22:27.064 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.064 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.065 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.066 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.066 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.067 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.068 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.068 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-06 22:22:27.110 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.124 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.143 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.148 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-06 22:22:27.149 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.151 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.183 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.184 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.188 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-10-06 22:22:27.189 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-06 22:22:27.189 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-06 22:22:27.190 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-06 22:22:27.191 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-06 22:22:27.191 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-06 22:22:27.192 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-06 22:22:27.192 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-06 22:22:27.193 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-06 22:22:27.194 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.196 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-5.78605122e+10 -1.28021117e+11 -5.55223125e+10] m
# 2025-10-06 22:22:27.197 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.197 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.197 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.198 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.198 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.199 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.199 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.200 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-06 22:22:27.200 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-06 22:22:27.223 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-06 22:22:27.227 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-06 22:22:27.228 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.229 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.278 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.280 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.326 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.327 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.369 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.371 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.439 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.441 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.495 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.498 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.536 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.537 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.554 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# WARNING: Could not find pulsar distance for PSR J2322+2057. Setting value to 1 with 20% uncertainty.
# 2025-10-06 22:22:27.587 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-06 22:22:27.589 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR J2322+2057 complete

# %%
#make a noise dict that  works 

#sarah's noise file
sarahs_noise_file = '/Users/ashokan/osu/sarahspta/20yr_noisedict_rn+curn-bpl.json'
import json
with open(sarahs_noise_file,'r') as f:
    noise = json.load(f)
rn_psrs = noise
#print(rn_psrs)

#Nihan's noise dict for 15yr 
nihans_dict = '/Users/ashokan/osu/sarahspta/15yr_v1_fl_fwn_dict.json'
with open(nihans_dict,'r') as f:
    nihans_noise = json.load(f)

#NG20 real noise dict
ng20_noise_dict = '/Users/ashokan/osu/sarahspta/ng20_v1p1_dmx_noise_dict.json'
#from https://drive.google.com/drive/folders/1GQXnpyRglqPHwgQs6vE8VK-6VoL9WbSj
with open(ng20_noise_dict,'r') as f:
    ng20_noise_real = json.load(f)

#make a new noise dict with only chime and vegas pulsars
chime_vegas_noise_dict = {}
for k, v in ng20_noise_real.items():
    new_key = k.replace("t2equad", "equad")
    if "CHIME" in k or "YUPPI" in k or "VEGAS" in k or "J0125-2327" in k or "J0154+1833" in k or "J0614-3329" in k or "J0621+2514" in k or "J0732+2314" in k or "J0751+1807" in k or "J1022+1001" in k or "J1803+1358" in k or "J2022+2534" in k or "J2039-3616" in k or "J2150-0326" in k:
        print(k)
        chime_vegas_noise_dict[new_key] = v

#update nihans noise dict with chime and vegas pulsars from ng20
nihans_noise.update(chime_vegas_noise_dict)
# Out:
# B1855+09_CHIME_efac
# B1855+09_CHIME_log10_ecorr
# B1855+09_CHIME_log10_t2equad
# B1855+09_Rcvr1_2_VEGAS_efac
# B1855+09_Rcvr1_2_VEGAS_log10_ecorr
# B1855+09_Rcvr1_2_VEGAS_log10_t2equad
# B1937+21_3GHz_YUPPI_efac
# B1937+21_3GHz_YUPPI_log10_ecorr
# B1937+21_3GHz_YUPPI_log10_t2equad
# B1937+21_CHIME_efac
# B1937+21_CHIME_log10_ecorr
# B1937+21_CHIME_log10_t2equad
# B1937+21_Rcvr1_2_VEGAS_efac
# B1937+21_Rcvr1_2_VEGAS_log10_ecorr
# B1937+21_Rcvr1_2_VEGAS_log10_t2equad
# B1937+21_Rcvr_800_VEGAS_efac
# B1937+21_Rcvr_800_VEGAS_log10_ecorr
# B1937+21_Rcvr_800_VEGAS_log10_t2equad
# B1953+29_CHIME_efac
# B1953+29_CHIME_log10_ecorr
# B1953+29_CHIME_log10_t2equad
# J0023+0923_CHIME_efac
# J0023+0923_CHIME_log10_ecorr
# J0023+0923_CHIME_log10_t2equad
# J0023+0923_Rcvr1_2_VEGAS_efac
# J0023+0923_Rcvr1_2_VEGAS_log10_ecorr
# J1600-3053_Rcvr_800_VEGAS_log10_ecorr
# J1600-3053_Rcvr_800_VEGAS_log10_t2equad
# J1614-2230_Rcvr1_2_VEGAS_efac
# J1614-2230_Rcvr1_2_VEGAS_log10_ecorr
# J1614-2230_Rcvr1_2_VEGAS_log10_t2equad
# J1614-2230_Rcvr_800_VEGAS_efac
# J1614-2230_Rcvr_800_VEGAS_log10_ecorr
# J1614-2230_Rcvr_800_VEGAS_log10_t2equad
# J1630+3734_CHIME_efac
# J1630+3734_CHIME_log10_ecorr
# J1630+3734_CHIME_log10_t2equad
# J1630+3734_Rcvr1_2_VEGAS_efac
# J1630+3734_Rcvr1_2_VEGAS_log10_ecorr
# J1630+3734_Rcvr1_2_VEGAS_log10_t2equad
# J1630+3734_Rcvr_800_VEGAS_efac
# J1630+3734_Rcvr_800_VEGAS_log10_ecorr
# J1630+3734_Rcvr_800_VEGAS_log10_t2equad
# J1640+2224_CHIME_efac
# J1640+2224_CHIME_log10_ecorr
# J1640+2224_CHIME_log10_t2equad
# J1640+2224_Rcvr1_2_VEGAS_efac
# J1640+2224_Rcvr1_2_VEGAS_log10_ecorr
# J1640+2224_Rcvr1_2_VEGAS_log10_t2equad
# J1643-1224_3GHz_YUPPI_efac
# J1643-1224_3GHz_YUPPI_log10_ecorr
# J1643-1224_3GHz_YUPPI_log10_t2equad
# J1643-1224_CHIME_efac
# J1643-1224_CHIME_log10_ecorr
# J1643-1224_CHIME_log10_t2equad
# J1643-1224_Rcvr1_2_VEGAS_efac
# J1643-1224_Rcvr1_2_VEGAS_log10_ecorr
# J1643-1224_Rcvr1_2_VEGAS_log10_t2equad
# J1643-1224_Rcvr_800_VEGAS_efac
# J1643-1224_Rcvr_800_VEGAS_log10_ecorr
# J1643-1224_Rcvr_800_VEGAS_log10_t2equad
# J1705-1903_3GHz_YUPPI_efac
# J1705-1903_3GHz_YUPPI_log10_ecorr
# J1705-1903_3GHz_YUPPI_log10_t2equad
# J1705-1903_Rcvr1_2_VEGAS_efac
# J1705-1903_Rcvr1_2_VEGAS_log10_ecorr
# J1705-1903_Rcvr1_2_VEGAS_log10_t2equad
# J1705-1903_Rcvr_800_VEGAS_efac
# J1705-1903_Rcvr_800_VEGAS_log10_ecorr
# J1705-1903_Rcvr_800_VEGAS_log10_t2equad
# J1713+0747_1.5GHz_YUPPI_efac
# J1713+0747_1.5GHz_YUPPI_log10_ecorr
# J1713+0747_1.5GHz_YUPPI_log10_t2equad
# J1713+0747_3GHz_YUPPI_efac
# J1713+0747_3GHz_YUPPI_log10_ecorr
# J1713+0747_3GHz_YUPPI_log10_t2equad
# J1713+0747_CHIME_efac
# J1713+0747_CHIME_log10_ecorr
# J1713+0747_CHIME_log10_t2equad
# J1713+0747_Rcvr1_2_VEGAS_efac
# J1713+0747_Rcvr1_2_VEGAS_log10_ecorr
# J1713+0747_Rcvr1_2_VEGAS_log10_t2equad
# J1713+0747_Rcvr_800_VEGAS_efac
# J1713+0747_Rcvr_800_VEGAS_log10_ecorr
# J1802-2124_3GHz_YUPPI_log10_t2equad
# J1802-2124_Rcvr1_2_VEGAS_efac
# J1802-2124_Rcvr1_2_VEGAS_log10_ecorr
# J1802-2124_Rcvr1_2_VEGAS_log10_t2equad
# J1802-2124_Rcvr_800_VEGAS_efac
# J1802-2124_Rcvr_800_VEGAS_log10_ecorr
# J1802-2124_Rcvr_800_VEGAS_log10_t2equad
# J1803+1358_CHIME_efac
# J1803+1358_CHIME_log10_ecorr
# J1803+1358_CHIME_log10_t2equad
# J1803+1358_L-wide_PUPPI_efac
# J1803+1358_L-wide_PUPPI_log10_ecorr
# J1803+1358_L-wide_PUPPI_log10_t2equad
# J1803+1358_Rcvr1_2_VEGAS_efac
# J1803+1358_Rcvr1_2_VEGAS_log10_ecorr
# J1803+1358_Rcvr1_2_VEGAS_log10_t2equad
# J1803+1358_red_noise_gamma
# J1803+1358_red_noise_log10_A
# J1811-2405_Rcvr1_2_VEGAS_efac
# J1811-2405_Rcvr1_2_VEGAS_log10_ecorr
# J1811-2405_Rcvr1_2_VEGAS_log10_t2equad
# J1811-2405_Rcvr_800_VEGAS_efac
# J1811-2405_Rcvr_800_VEGAS_log10_ecorr
# J1811-2405_Rcvr_800_VEGAS_log10_t2equad
# J1832-0836_Rcvr1_2_VEGAS_efac
# J1832-0836_Rcvr1_2_VEGAS_log10_ecorr
# J1832-0836_Rcvr1_2_VEGAS_log10_t2equad
# J1832-0836_Rcvr_800_VEGAS_efac
# J1832-0836_Rcvr_800_VEGAS_log10_ecorr
# J1832-0836_Rcvr_800_VEGAS_log10_t2equad
# J1843-1113_Rcvr1_2_VEGAS_efac
# J1843-1113_Rcvr1_2_VEGAS_log10_ecorr
# J1843-1113_Rcvr1_2_VEGAS_log10_t2equad
# J1843-1113_Rcvr_800_VEGAS_efac
# J1843-1113_Rcvr_800_VEGAS_log10_ecorr
# J1843-1113_Rcvr_800_VEGAS_log10_t2equad
# J1853+1303_CHIME_efac
# J1853+1303_CHIME_log10_ecorr
# J1853+1303_CHIME_log10_t2equad
# J1853+1303_Rcvr1_2_VEGAS_efac
# J1853+1303_Rcvr1_2_VEGAS_log10_ecorr
# J1853+1303_Rcvr1_2_VEGAS_log10_t2equad
# J1903+0327_3GHz_YUPPI_efac
# J1903+0327_3GHz_YUPPI_log10_ecorr
# J1903+0327_3GHz_YUPPI_log10_t2equad
# J1903+0327_Rcvr1_2_VEGAS_efac
# J1903+0327_Rcvr1_2_VEGAS_log10_ecorr
# J1903+0327_Rcvr1_2_VEGAS_log10_t2equad
# J1909-3744_3GHz_YUPPI_efac
# J1909-3744_3GHz_YUPPI_log10_ecorr
# J1909-3744_3GHz_YUPPI_log10_t2equad
# J1909-3744_Rcvr1_2_VEGAS_efac
# J1909-3744_Rcvr1_2_VEGAS_log10_ecorr
# J1909-3744_Rcvr1_2_VEGAS_log10_t2equad
# J1909-3744_Rcvr_800_VEGAS_efac
# J1909-3744_Rcvr_800_VEGAS_log10_ecorr
# J1909-3744_Rcvr_800_VEGAS_log10_t2equad
# J2150-0326_Rcvr_800_GUPPI_efac
# J2150-0326_Rcvr_800_GUPPI_log10_ecorr
# J2150-0326_Rcvr_800_GUPPI_log10_t2equad
# J2150-0326_Rcvr_800_VEGAS_efac
# J2150-0326_Rcvr_800_VEGAS_log10_ecorr
# J2150-0326_Rcvr_800_VEGAS_log10_t2equad
# J2150-0326_red_noise_gamma
# J2150-0326_red_noise_log10_A
# J2214+3000_3GHz_YUPPI_efac
# J2214+3000_3GHz_YUPPI_log10_ecorr
# J2214+3000_3GHz_YUPPI_log10_t2equad
# J2214+3000_CHIME_efac
# J2214+3000_CHIME_log10_ecorr
# J2214+3000_CHIME_log10_t2equad
# J2214+3000_Rcvr1_2_VEGAS_efac
# J2214+3000_Rcvr1_2_VEGAS_log10_ecorr
# J2214+3000_Rcvr1_2_VEGAS_log10_t2equad
# J2229+2643_CHIME_efac
# J2229+2643_CHIME_log10_ecorr
# J2229+2643_CHIME_log10_t2equad
# J2229+2643_Rcvr1_2_VEGAS_efac
# J2229+2643_Rcvr1_2_VEGAS_log10_ecorr
# J2229+2643_Rcvr1_2_VEGAS_log10_t2equad
# J2234+0611_CHIME_efac
# J2234+0611_CHIME_log10_ecorr
# J2234+0611_CHIME_log10_t2equad
# J2234+0611_Rcvr1_2_VEGAS_efac
# J2234+0611_Rcvr1_2_VEGAS_log10_ecorr
# J2234+0611_Rcvr1_2_VEGAS_log10_t2equad
# J2234+0944_CHIME_efac
# J2234+0944_CHIME_log10_ecorr
# J2234+0944_CHIME_log10_t2equad
# J2234+0944_Rcvr1_2_VEGAS_efac
# J2234+0944_Rcvr1_2_VEGAS_log10_ecorr
# J2234+0944_Rcvr1_2_VEGAS_log10_t2equad
# J2302+4442_CHIME_efac
# J2302+4442_CHIME_log10_ecorr
# J2302+4442_CHIME_log10_t2equad
# J2302+4442_Rcvr1_2_VEGAS_efac
# J2302+4442_Rcvr1_2_VEGAS_log10_ecorr
# J2302+4442_Rcvr1_2_VEGAS_log10_t2equad
# J2302+4442_Rcvr_800_VEGAS_efac
# J2302+4442_Rcvr_800_VEGAS_log10_ecorr
# J2302+4442_Rcvr_800_VEGAS_log10_t2equad
# J2317+1439_CHIME_efac
# J2317+1439_CHIME_log10_ecorr
# J2317+1439_CHIME_log10_t2equad
# J2317+1439_Rcvr1_2_VEGAS_efac
# J2317+1439_Rcvr1_2_VEGAS_log10_ecorr
# J2317+1439_Rcvr1_2_VEGAS_log10_t2equad
# J2322+2057_CHIME_efac
# J2322+2057_CHIME_log10_ecorr
# J2322+2057_CHIME_log10_t2equad
# J2322+2057_Rcvr1_2_VEGAS_efac
# J2322+2057_Rcvr1_2_VEGAS_log10_ecorr
# J2322+2057_Rcvr1_2_VEGAS_log10_t2equad

# %%
def make_corr(psr,noise):
    N = psr.toaerrs.size
    corr = np.zeros((N,N))
    _, _, fl, _, bi = hsen.quantize_fast(psr.toas,psr.toaerrs,
                                         flags=psr.flags['f'],dt=1)
    keys = [ky for ky in noise.keys() if psr.name in ky]
    backends = np.unique(psr.flags['f'])
    sigma_sqr = np.zeros(N)
    ecorrs = np.zeros_like(fl,dtype=float)
    for be in backends:
        mask = np.where(psr.flags['f']==be)
        key_ef = '{0}_{1}_{2}'.format(psr.name,be,'efac')
        key_eq = '{0}_{1}_log10_{2}'.format(psr.name,be,'equad')
        key_ec = '{0}_{1}_log10_{2}'.format(psr.name,be,'ecorr')
        sigma_sqr[mask] = (noise[key_ef]**2 * ((psr.toaerrs[mask]**2)
                           + (10**noise[key_eq])**2))#+(10**noise[key_ec])**2)
        mask_ec = np.where(fl==be)
        key_ec = '{0}_{1}_log10_{2}'.format(psr.name,be,'ecorr')
        ecorrs[mask_ec] = np.ones_like(mask_ec) * (10**noise[key_ec])
    j = [ecorrs[ii]**2*np.ones((len(bucket),len(bucket)))
         for ii, bucket in enumerate(bi)]

    J = sl.block_diag(*j)
    corr = np.diag(sigma_sqr) + J
    return corr

# %%
#make correlation matrix with only toaerrs for Sarah's data
def make_corr_our(psr):
    sigma_sqrt = psr.toaerrs**2
    corr = np.diag(sigma_sqrt)
    return corr

# %%
Tspan = hsen.get_Tspan(ePsrs)
fyr = 1/(365.25*24*3600)
freqs = np.logspace(np.log10(1/(5*Tspan)),np.log10(2e-7),600)

# %%
#make hasasia pulsars from enterprise pulsars.
A_gwb, gamma_gwb = 6.4e-15, 3.2 # median values from detection paper
psrs = []
thin = 1
for ePsr in ePsrs:
    corr = make_corr_our(ePsr)[::thin,::thin]
    nihans_corr = make_corr(ePsr,nihans_noise)
    plaw = hsen.red_noise_powerlaw(A=A_gwb, gamma=gamma_gwb, freqs=freqs)
    if ePsr.name in rn_psrs.keys():
        Amp, gam = rn_psrs[ePsr.name]
        plaw += hsen.red_noise_powerlaw(A=10**Amp, gamma=gam, freqs=freqs)

    nihans_corr += hsen.corr_from_psd(freqs=freqs, psd=plaw,
                               toas=ePsr.toas[::thin])
    psr = hsen.Pulsar(toas=ePsr.toas[::thin],
                      toaerrs=ePsr.toaerrs[::thin],
                      phi=ePsr.phi,theta=ePsr.theta,
                      N=nihans_corr, designmatrix=ePsr.Mmat[::thin,:])
    psr.name = ePsr.name
    psrs.append(psr)
    del ePsr
    print('\rPSR {0} complete'.format(psr.name),end='',flush=True)
# Out:
# PSR J2322+2057 complete

# %%
#make spectra
specs = []
for p in psrs:
    sp = hsen.Spectrum(p, freqs=freqs,amp_gw=None, gamma_gw=None)
    _ = sp.NcalInv
    specs.append(sp)
    print('\rPSR {0} complete'.format(p.name),end='',flush=True)
ng20_sarah_nihans_wn = hsen.GWBSensitivityCurve(specs)
# Out:
# PSR J2322+2057 complete

# %%
#plot against original NG15 curve
ng15_pkl_gwb = '/Users/ashokan/osu/sarahspta/ng15yr_v1p1_pint_logf_m2a_red_noise_vg_gwbsc.has' 
with open (ng15_pkl_gwb,'rb') as f:
    ng15_sc_gwb = pickle.load(f)

plt.loglog(ng20_sarah_nihans_wn.freqs,ng20_sarah_nihans_wn.h_c,label='NANOGrav 20-yr with Nihan\'s WN')
plt.loglog(ng15_sc_gwb.freqs,ng15_sc_gwb.h_c,label='NANOGrav 15-yr')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Characteristic Strain, $h_c$')
plt.title('NANOGrav 20-15-year Data Set Sensitivity Curve')
plt.grid(which='both')
# plt.ylim(1e-15,9e-12)
plt.legend()
plt.show()

# %%
#SNR of full NG20 data now
alpha_gwb = (3. - gamma_gwb) / 2.
S_h = hsen.S_h(A=A_gwb, alpha=alpha_gwb, freqs=freqs)
snr_20 = ng20_sarah_nihans_wn.SNR(S_h)
print(snr_20)
# Out:
# 9.608146898021845

# %% [markdown]
# Okay that is how the full NG20 dataset from Sarah looks like in comparison to NG15. Now lets slice it to 15 year.

# %%
def get_sliced_spectra(psrs, 
                       start_mjd=1,
                       end_mjd = None,
                       ):
    """
    Parameters 
    ----------
    
    psrs : list of enterprise.Pulsar or list of hasasia.Pulsar objects
        List of enterprise/hasasia Pulsar objects
        
    cutoff : float
        MJD cutoff for the calculation
    
    sigma_correction : ?
        ???
    """
    psrs_cut = []
    psrs_copy = copy.deepcopy(psrs)
    for idx, psr in enumerate(psrs_copy):
        # filter the data around to the appropriate slice
        #print("N_toa = ", len(psr.toas))
        psr.filter_data(start_time=start_mjd, end_time=end_mjd)
        #print("after filter = ", len(psr.toas)) 
        # If there are no TOAs remaining, or the time span of the pulsar is <3 cut.
        if (psr.toas.size == 0) or (hsen.get_Tspan([psr]) < 3*365.25*24*3600):
            #idxs.append(idx)
           pass
        else:
            psrs_cut.append(psr)
    timespan = hsen.get_Tspan(psrs_cut)
    spectra = []
    for idx, p in enumerate(psrs_cut):
        sp = hsen.Spectrum(p, freqs=freqs,amp_gw=None, gamma_gw=None)
        sp.name = p.name
        _ = sp.NcalInv
        #print(f"psr spectra {idx} is done")
        spectra.append(sp)
    print(f"PTA spectrum with {len(spectra)} psrs created.")
    return spectra

# %%
end_mjd = 59033
psr_spectra = get_sliced_spectra(psrs, 
                       start_mjd=1,
                       end_mjd = end_mjd,
                       )
# Out:
# PTA spectrum with 64 psrs created.

# %%
#SNR of sliced data
sliced_GWBSC = hsen.GWBSensitivityCurve(spectra=psr_spectra, orf='hd', autocorr=False)
S_h = hsen.S_h(A=A_gwb, alpha=alpha_gwb, freqs=freqs)
sliced_SNR = sliced_GWBSC.SNR(S_h)
print(sliced_SNR)
# Out:
# 5.995589315914723

# %%
print(len(psrs))
print(len(psr_spectra)) #If there are no TOAs remaining or < 3 years of data pulsar gets left out
# Out:
# 77
# 64

# %%
#plot 15year slice of NG20 against NG15
plt.loglog(sliced_GWBSC.freqs,sliced_GWBSC.h_c,label='15year slice of NANOGrav 20-yr')
plt.loglog(ng15_sc_gwb.freqs,ng15_sc_gwb.h_c,label='NANOGrav 15-yr')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Characteristic Strain, $h_c$')
plt.title(
'NANOGrav Sensitivity Curves, tuned w 15year WN, SNR={:.2f}'.format(
    sliced_SNR
)
)

#plt.title('NANOGrav Sensitivity Curves, tuned with FACTOR={:.4f}'.format(FACTOR),'SNR={:.2f}'.format(sliced_with_factor_SNR))

plt.grid(which='both')
# plt.ylim(1e-15,9e-12)
plt.legend()
plt.show()

# %% [markdown]
# Okay this has an SNR of 6
# We want it to be 5 as was in the original NG15 analysis.

# %% [markdown]
# Lets tune its white noise.

# %% [markdown]
# We'll have to use enterprise pulsar objects and chop because hasasia pulsars have no flags etc and their ecorr equad etc become a pain to use in the expression for sigma^2

# %%
#We tune by multiplying toaerrs by a FACTOR
def make_corr_our_tuning_with_all_wn(psr,noise,FACTOR=1.0):
    N = psr.toaerrs.size
    corr = np.zeros((N,N))
    _, _, fl, _, bi = hsen.quantize_fast(psr.toas,psr.toaerrs,
                                         flags=psr.flags['f'],dt=1)
    keys = [ky for ky in noise.keys() if psr.name in ky]
    backends = np.unique(psr.flags['f'])
    sigma_sqr = np.zeros(N)
    ecorrs = np.zeros_like(fl,dtype=float)
    for be in backends:
        mask = np.where(psr.flags['f']==be)
        key_ef = '{0}_{1}_{2}'.format(psr.name,be,'efac')
        key_eq = '{0}_{1}_log10_{2}'.format(psr.name,be,'equad')
        key_ec = '{0}_{1}_log10_{2}'.format(psr.name,be,'ecorr')
        sigma_sqr[mask] = (noise[key_ef]**2 * (FACTOR*(psr.toaerrs[mask]**2)
                           + (10**noise[key_eq])**2))#+(10**noise[key_ec])**2)
        mask_ec = np.where(fl==be)
        key_ec = '{0}_{1}_log10_{2}'.format(psr.name,be,'ecorr')
        ecorrs[mask_ec] = np.ones_like(mask_ec) * (10**noise[key_ec])
    j = [ecorrs[ii]**2*np.ones((len(bucket),len(bucket)))
         for ii, bucket in enumerate(bi)]

    J = sl.block_diag(*j)
    corr = np.diag(sigma_sqr) + J
    return corr

# %% [markdown]
# Lets try to chop enterprise pulsars instead of hasasia pulsars.

# %%
def get_sliced_epulsars(psrs, 
                       start_mjd=1,
                       end_mjd = None,
                       ):
    """
    Parameters 
    ----------
    
    psrs : list of enterprise.Pulsar or list of hasasia.Pulsar objects
        List of enterprise/hasasia Pulsar objects

    start_mjd : float
        MJD start time for the calculation

    end_mjd : float
        MJD end time for the calculation
    """
    psrs_cut = []
    psrs_copy = copy.deepcopy(psrs)
    for idx, psr in enumerate(psrs_copy):
        # filter the data around to the appropriate slice
        #print("N_toa = ", len(psr.toas))
        psr.filter_data(start_time=start_mjd, end_time=end_mjd)
        #print("after filter = ", len(psr.toas)) 
        # If there are no TOAs remaining, or the time span of the pulsar is <3 cut.
        if (psr.toas.size == 0) or (hsen.get_Tspan([psr]) < 3*365.25*24*3600):
    #         idxs.append(idx)
            pass
        else:
            psrs_cut.append(psr)
    return psrs_cut

# %%
end_mjd = 59033
epsrs_cut_NG15 = get_sliced_epulsars(ePsrs, 
                       start_mjd=1,
                       end_mjd = end_mjd,
                       )

# %%
print(len(ePsrs))
print(len(epsrs_cut_NG15)) #once again if no TOAs or < 3 years of data pulsar gets left out
# Out:
# 77
# 64

# %% [markdown]
# ## Loop over prefactors

# %%
sliced_15yr_SNRS = []
for prefactor in [0.5,0.6,0.7,0.8,2]:
    FACTOR = prefactor*1.45*np.sqrt(np.pi)
    print("FACTOR = ", FACTOR)    
    A_gwb, gamma_gwb = 6.4e-15, 3.2 # median values from detection paper
    psrs = []
    thin = 1
    for ePsr in epsrs_cut_NG15:
        nihans_corr = make_corr_our_tuning_with_all_wn(ePsr,nihans_noise,FACTOR=FACTOR)
        plaw = hsen.red_noise_powerlaw(A=A_gwb, gamma=gamma_gwb, freqs=freqs)
        if ePsr.name in rn_psrs.keys():
            Amp, gam = rn_psrs[ePsr.name]
            plaw += hsen.red_noise_powerlaw(A=10**Amp, gamma=gam, freqs=freqs)

        nihans_corr += hsen.corr_from_psd(freqs=freqs, psd=plaw,
                                toas=ePsr.toas[::thin])
        psr = hsen.Pulsar(toas=ePsr.toas[::thin],
                        toaerrs=ePsr.toaerrs[::thin],
                        phi=ePsr.phi,theta=ePsr.theta,
                        N=nihans_corr, designmatrix=ePsr.Mmat[::thin,:])
        psr.name = ePsr.name
        psrs.append(psr)
        del ePsr
    print('\rPSR {0} complete'.format(psr.name),end='',flush=True)

    specs = []
    for p in psrs:
        sp = hsen.Spectrum(p, freqs=freqs,amp_gw=None, gamma_gw=None)
        _ = sp.NcalInv
        specs.append(sp)
        #print('\rPSR {0} complete'.format(p.name),end='',flush=True)

    ng20_sarah_sc_with_factor = hsen.GWBSensitivityCurve(specs)
    sliced_with_factor_SNR = ng20_sarah_sc_with_factor.SNR(S_h)
    sliced_15yr_SNRS.append(sliced_with_factor_SNR)
    print("sliced_with_factor_SNR = ", sliced_with_factor_SNR)

    plt.loglog(ng20_sarah_sc_with_factor.freqs,ng20_sarah_sc_with_factor.h_c,label='15year slice of NANOGrav 20-yr')
    plt.loglog(ng15_sc_gwb.freqs,ng15_sc_gwb.h_c,label='NANOGrav 15-yr')
    plt.xlabel('Frequency [Hz]')
    plt.ylabel('Characteristic Strain, $h_c$')
    plt.title(
    'NANOGrav Sensitivity Curves, tuned with FACTOR={:.4f}, SNR={:.2f}'.format(
        FACTOR, sliced_with_factor_SNR
    )
)
    #plt.title('NANOGrav 20-15-year Data Set Sensitivity Curve, tuned with FACTOR={0}'.format(FACTOR))
    plt.grid(which='both')
    # plt.ylim(1e-15,9e-12)
    plt.legend()
    plt.show()
# Out:
# FACTOR =  1.285029041906499
# PSR J2322+2057 completesliced_with_factor_SNR =  5.491158695897491
# FACTOR =  1.5420348502877987
# PSR J2322+2057 completesliced_with_factor_SNR =  5.2402085640686575
# FACTOR =  1.7990406586690983
# PSR J2322+2057 completesliced_with_factor_SNR =  5.0277732082283695
# FACTOR =  2.056046467050398
# PSR J2322+2057 completesliced_with_factor_SNR =  4.84397155402072
# FACTOR =  5.140116167625996
# PSR J2322+2057 completesliced_with_factor_SNR =  3.615021216725699

# %% [markdown]
# The last one is just to show that the sensitivity curve is being affected by the factor although it might not seem like it with the first three values of factor!

# %% [markdown]
# ### So to conclude, if you use a factor of 1.5420348502877987 on toaerror, and use the noise dict formed by the combination of 15year WN + (CHIME, VEGAS, extra pulsars) from real NG20, then you will get an SNR of 5 on the NG15 slice of the simulated NG20 dataset.
