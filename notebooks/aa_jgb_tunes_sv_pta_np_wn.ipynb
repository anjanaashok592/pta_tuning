# %%
import pickle, copy, json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as ticker
import matplotlib as mpl
import matplotlib.cm as cm
import scipy.stats as sps
from random import shuffle
import itertools

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
#import la_forge.utils as lf_utils
#lf_utils.set_publication_params({'text.usetex':False})
#fig_dir = '/home/baierj/projects/hasasia2/hasasia2_paper/figures'

# %%
import healpy as hp
import astropy.units as u
import astropy.constants as c
from astropy.coordinates import SkyCoord
#import plot #Script originally written by Leo Stein for making pretty sky maps. 

# Setting various healpy quantities and GW source sky positions.
NSIDE = 8
NPIX = hp.nside2npix(NSIDE)
IPIX = np.arange(NPIX)
theta_gw, phi_gw = hp.pix2ang(nside=NSIDE,ipix=IPIX)

# %%
import numpy as np
import scipy.linalg as sl
import matplotlib.pyplot as plt
# %matplotlib inline
import glob, pickle, json
import hasasia.sensitivity as hsen
import hasasia.sim as hsim
import hasasia.skymap as hsky
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
mpl.rcParams['figure.figsize'] = [5,3]
mpl.rcParams['text.usetex'] = True
from enterprise.pulsar import Pulsar as ePulsar
# Out:
# /opt/homebrew/Caskroom/mambaforge/base/envs/sarahspta/lib/python3.12/site-packages/enterprise/signals/utils.py:13: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import Requirement, resource_filename
# libstempo not installed. PINT or libstempo are required to use par and tim files.
# RuntimeWarning: This platform does not support extended precision floating-point, and PINT will run at reduced precision.

# %%
#get Sarah's data
ng20_irn = '/Users/ashokan/osu/sarahspta/NG20_irn/'
pardir = ng20_irn
timdir = ng20_irn
pars = sorted(glob.glob(pardir+'*.par'))
tims = sorted(glob.glob(timdir+'*.tim'))

# %%
#check number of pulsars
print(len(pars))
print(len(tims))
# Out:
# 77
# 77

# %%
#check first par and tim files
print(pars[0])
print(tims[0])
# Out:
# /Users/ashokan/osu/sarahspta/NG20_irn/B1855+09.par
# /Users/ashokan/osu/sarahspta/NG20_irn/B1855+09.tim

# %%
#make enterprise pulsars
ePsrs = []
for par,tim in zip(pars,tims):
    ePsr = ePulsar(par, tim,  ephem='DE440')
    ePsrs.append(ePsr)
    print('\rPSR {0} complete'.format(ePsr.name),end='',flush=True)
# Out:
# 2025-10-03 17:47:52.498 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2021 from the given model
# 2025-10-03 17:47:52.701 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-03 17:47:52.703 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-03 17:47:52.713 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:52.713 | DEBUG    | pint.observatory:_load_gps_clock:108 - Loading global GPS clock file
# 2025-10-03 17:47:52.746 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file gps2utc.clk saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-10-03 17:47:52.759 | DEBUG    | pint.observatory.clock_file:read_tempo2_clock_file:463 - Loading TEMPO2-format observatory clock correction file gps2utc.clk (/Users/ashokan/.astropy/cache/download/url/d3c81b5766f4bfb84e65504c8a453085/contents) with bogus_last_correction=False
# 2025-10-03 17:47:52.774 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for gps2utc.clk with bogus_last_correction=False
# 2025-10-03 17:47:52.776 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-03 17:47:52.776 | INFO     | pint.observatory:_load_bipm_clock:119 - Loading BIPM clock version bipm2021
# 2025-10-03 17:47:52.778 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file tai2tt_bipm2021.clk saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-10-03 17:47:52.796 | DEBUG    | pint.observatory.clock_file:read_tempo2_clock_file:463 - Loading TEMPO2-format observatory clock correction file tai2tt_bipm2021.clk (/Users/ashokan/.astropy/cache/download/url/e00edeef4edde217d65207a9abeb6a8c/contents) with bogus_last_correction=False
# 2025-10-03 17:47:52.800 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for tai2tt_bipm2021.clk with bogus_last_correction=False
# 2025-10-03 17:47:52.802 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file time_ao.dat saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-10-03 17:47:52.821 | DEBUG    | pint.observatory.clock_file:read_tempo_clock_file:613 - Loading TEMPO-format observatory clock correction file time_ao.dat (/Users/ashokan/.astropy/cache/download/url/36fe8d7a16ab23eeb27a998de5b7eea4/contents) with bogus_last_correction=False
# 2025-10-03 17:47:52.831 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for time_ao.dat with bogus_last_correction=False
# 2025-10-03 17:47:52.832 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-03 17:47:52.916 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:52.917 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# UserWarning: Data points out of range in clock file 'tai2tt_bipm2021.clk'
# 2025-10-03 17:47:52.919 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-03 17:47:53.023 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:53.024 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-03 17:47:53.027 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file time_gbt.dat saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-10-03 17:47:53.043 | DEBUG    | pint.observatory.clock_file:read_tempo_clock_file:613 - Loading TEMPO-format observatory clock correction file time_gbt.dat (/Users/ashokan/.astropy/cache/download/url/599e3ebbfc317e090244ee1ef4c79374/contents) with bogus_last_correction=False
# 2025-10-03 17:47:53.043 | INFO     | pint.observatory.clock_file:read_tempo_clock_file:703 - Disregarding suspicious MJD -2271.5 in TEMPO clock file
# 2025-10-03 17:47:53.053 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for time_gbt.dat with bogus_last_correction=False
# 2025-10-03 17:47:53.054 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='gbt'.
# 2025-10-03 17:47:53.060 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-03 17:47:53.061 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-03 17:47:53.109 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-03 17:47:53.110 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-03 17:47:53.256 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.663 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [5.39316141e+09 1.34911428e+11 5.84771576e+10] m
# 2025-10-03 17:47:53.664 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.666 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.667 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.668 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.672 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.673 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.674 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.698 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.729 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-7.93797492e+09 -1.38231720e+11 -5.99234428e+10] m
# 2025-10-03 17:47:53.730 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.732 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.734 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.735 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.736 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.738 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.739 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.741 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.745 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.48209377e+11  2.02008500e+10  8.78368581e+09] m
# 2025-10-03 17:47:53.746 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.747 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.748 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.748 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.749 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.750 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.750 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.751 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-03 17:47:53.789 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.814 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.847 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.853 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-03 17:47:53.854 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:53.857 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:53.884 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:53.885 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:53.895 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-10-03 17:47:53.897 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-03 17:47:53.897 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-03 17:47:53.898 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:53.899 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-03 17:47:53.900 | INFO     | pint.observatory:_load_bipm_clock:119 - Loading BIPM clock version bipm2023
# 2025-10-03 17:47:53.901 | DEBUG    | pint.observatory.clock_file:__init__:812 - Global clock file tai2tt_bipm2023.clk saving kwargs={'bogus_last_correction': False, 'valid_beyond_ends': False}
# 2025-10-03 17:47:53.913 | DEBUG    | pint.observatory.clock_file:read_tempo2_clock_file:463 - Loading TEMPO2-format observatory clock correction file tai2tt_bipm2023.clk (/Users/ashokan/.astropy/cache/download/url/d0c6b0f6a57e39d4a167cd2aa08ad383/contents) with bogus_last_correction=False
# 2025-10-03 17:47:53.917 | INFO     | pint.observatory:find_clock_file:973 - Using global clock file for tai2tt_bipm2023.clk with bogus_last_correction=False
# 2025-10-03 17:47:53.918 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-03 17:47:53.920 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-03 17:47:53.921 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-03 17:47:53.923 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-03 17:47:53.924 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.926 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.49328670e+11  6.35100491e+09  2.76121816e+09] m
# 2025-10-03 17:47:53.927 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.928 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.929 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.929 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.930 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.932 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.933 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.933 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-03 17:47:53.935 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-03 17:47:53.969 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:53.977 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-03 17:47:53.978 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:53.981 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.054 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.057 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.115 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.117 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.167 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.169 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.210 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.213 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.262 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.264 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.309 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.310 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.369 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.370 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.413 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.415 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.474 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.476 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.530 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.532 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.583 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.585 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.604 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.653 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:54.654 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR B1855+09 complete
# 2025-10-03 17:47:54.725 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2021 from the given model
# 2025-10-03 17:47:54.795 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-03 17:47:54.796 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-03 17:47:54.802 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:54.803 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-03 17:47:54.803 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-03 17:47:54.843 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:54.844 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# UserWarning: Data points out of range in clock file 'tai2tt_bipm2021.clk'
# 2025-10-03 17:47:54.848 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-03 17:47:54.924 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-03 17:47:54.925 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-03 17:47:54.964 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-03 17:47:54.964 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-03 17:47:55.058 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.075 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 6.39615815e+10 -1.26375641e+11 -5.47812334e+10] m
# 2025-10-03 17:47:55.076 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.078 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.080 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.082 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.085 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.086 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.087 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.098 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.133 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.19388263e+11 -8.35025455e+10 -3.61964919e+10] m
# 2025-10-03 17:47:55.134 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.136 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.137 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.139 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.141 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.142 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.143 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.145 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-03 17:47:55.175 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.193 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.213 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-03 17:47:55.214 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.216 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.249 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.251 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.268 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-10-03 17:47:55.270 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-03 17:47:55.271 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-03 17:47:55.272 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:55.273 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-03 17:47:55.274 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-03 17:47:55.275 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-03 17:47:55.276 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-03 17:47:55.278 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-03 17:47:55.280 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.282 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 4.17618730e+10 -1.34483104e+11 -5.83157546e+10] m
# 2025-10-03 17:47:55.283 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.284 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.285 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.285 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.286 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.287 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.288 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.289 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-03 17:47:55.290 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-03 17:47:55.323 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:55.327 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-03 17:47:55.328 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.330 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.390 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.391 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.429 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.431 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.485 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.489 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.547 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.550 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.618 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.620 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.702 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.704 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.780 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.781 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.850 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.852 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.907 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.910 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.953 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:55.955 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:56.002 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:56.004 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:56.064 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:56.068 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:56.089 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:56.131 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:56.134 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR B1953+29 complete
# 2025-10-03 17:47:56.217 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2021 from the given model
# 2025-10-03 17:47:56.377 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-03 17:47:56.380 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-03 17:47:56.385 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:56.386 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-03 17:47:56.388 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-03 17:47:56.438 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:56.439 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# UserWarning: Data points out of range in clock file 'tai2tt_bipm2021.clk'
# 2025-10-03 17:47:56.443 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-03 17:47:56.581 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:56.582 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-03 17:47:56.586 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='gbt'.
# 2025-10-03 17:47:56.596 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-03 17:47:56.597 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-03 17:47:56.660 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-03 17:47:56.661 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-03 17:47:56.663 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.676 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.42573928e+11  3.86926049e+10  1.67754082e+10] m
# 2025-10-03 17:47:56.676 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.677 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.679 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.681 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.682 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.683 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.684 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.702 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.742 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 1.08241462e+11 -9.60944106e+10 -4.16553595e+10] m
# 2025-10-03 17:47:56.743 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.745 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.747 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.748 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.750 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.752 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.753 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.755 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.759 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.49334981e+11  1.22473747e+10  5.33256030e+09] m
# 2025-10-03 17:47:56.759 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.760 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.761 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.761 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.762 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.762 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.763 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.764 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-03 17:47:56.804 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.824 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.866 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.871 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-03 17:47:56.873 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:56.874 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:56.909 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:56.911 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:56.926 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-10-03 17:47:56.928 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-03 17:47:56.929 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-03 17:47:56.930 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:56.931 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-03 17:47:56.932 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-03 17:47:56.933 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-03 17:47:56.934 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-03 17:47:56.937 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-03 17:47:56.938 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.941 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 5.87710243e+10 -1.29005528e+11 -5.59435250e+10] m
# 2025-10-03 17:47:56.942 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.942 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.943 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.944 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.945 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.946 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.947 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.947 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-03 17:47:56.949 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-03 17:47:56.984 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:56.987 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-03 17:47:56.988 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:56.989 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.047 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.049 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.092 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.095 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.155 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.157 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.214 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.216 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.259 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.260 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.339 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.341 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.385 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.390 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.440 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.442 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.486 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.488 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.532 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.534 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.577 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.579 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.621 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.623 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.671 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.672 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.724 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.726 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.784 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.786 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.857 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.860 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.885 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# WARNING: Could not find pulsar distance for PSR J0023+0923. Setting value to 1 with 20% uncertainty.
# 2025-10-03 17:47:57.915 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:47:57.918 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR J0023+0923 complete
# 2025-10-03 17:47:57.971 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2021 from the given model
# 2025-10-03 17:47:58.155 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-03 17:47:58.158 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-03 17:47:58.173 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:58.175 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-03 17:47:58.175 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-03 17:47:58.281 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:58.282 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# UserWarning: Data points out of range in clock file 'tai2tt_bipm2021.clk'
# 2025-10-03 17:47:58.288 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-03 17:47:58.416 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:47:58.417 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-03 17:47:58.419 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='gbt'.
# 2025-10-03 17:47:58.425 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-03 17:47:58.425 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-03 17:47:58.575 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-03 17:47:58.577 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-03 17:47:58.593 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.625 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-8.36297648e+10  1.10796443e+11  4.80187109e+10] m
# 2025-10-03 17:47:58.625 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.626 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.627 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.628 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.629 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.630 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.631 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.639 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.674 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 1.08643378e+11 -9.57127228e+10 -4.14874860e+10] m
# 2025-10-03 17:47:58.675 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.678 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.681 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.682 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.683 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.684 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.685 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.688 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.692 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.49340830e+11  1.21982273e+10  5.31103108e+09] m
# 2025-10-03 17:47:58.693 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.693 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:47:58.694 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# ...
# 2025-10-03 17:49:20.226 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-03 17:49:20.248 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:20.251 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-03 17:49:20.252 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.253 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.310 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.314 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.346 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.348 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.391 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.393 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.446 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.448 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.494 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.496 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.548 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.550 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.615 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.617 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.661 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.663 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.714 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.716 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.759 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.760 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.806 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.807 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.864 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.865 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.883 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.914 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:20.918 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR J2317+1439 complete
# 2025-10-03 17:49:20.979 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2021 from the given model
# 2025-10-03 17:49:21.075 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-03 17:49:21.076 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-03 17:49:21.081 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:49:21.081 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-03 17:49:21.082 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-03 17:49:21.110 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:49:21.111 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# UserWarning: Data points out of range in clock file 'tai2tt_bipm2021.clk'
# 2025-10-03 17:49:21.114 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-03 17:49:21.160 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:49:21.161 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2021) clock correction (~27 us)
# 2025-10-03 17:49:21.163 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='gbt'.
# 2025-10-03 17:49:21.169 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-03 17:49:21.170 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-03 17:49:21.202 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-03 17:49:21.202 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-03 17:49:21.205 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.217 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.32090790e+11  6.03101032e+10  2.61245816e+10] m
# 2025-10-03 17:49:21.217 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.218 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.218 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.219 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.219 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.220 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.220 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.224 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.242 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.18404074e+11 -8.46988267e+10 -3.67168762e+10] m
# 2025-10-03 17:49:21.243 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.244 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.244 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.245 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.246 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.247 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.247 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.251 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.260 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.47905662e+11  2.18445975e+10  9.49398036e+09] m
# 2025-10-03 17:49:21.260 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.261 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.262 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.263 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.264 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.265 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.266 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.267 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-03 17:49:21.302 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.324 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.344 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.349 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-03 17:49:21.349 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.350 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.390 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.392 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.396 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-10-03 17:49:21.397 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-03 17:49:21.398 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-03 17:49:21.398 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-03 17:49:21.399 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-03 17:49:21.399 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-03 17:49:21.400 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-03 17:49:21.401 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-03 17:49:21.402 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-03 17:49:21.403 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.405 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-5.78605122e+10 -1.28021117e+11 -5.55223125e+10] m
# 2025-10-03 17:49:21.406 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.406 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.407 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.407 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.408 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.408 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.409 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.409 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-03 17:49:21.410 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-03 17:49:21.434 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-03 17:49:21.437 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-03 17:49:21.437 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.438 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.491 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.493 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.524 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.526 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.568 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.569 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.614 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.615 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.662 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.664 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.718 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.720 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.740 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# WARNING: Could not find pulsar distance for PSR J2322+2057. Setting value to 1 with 20% uncertainty.
# 2025-10-03 17:49:21.771 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-03 17:49:21.772 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR J2322+2057 complete

# %%
#make a noise dict that  works 

#sarah's noise file
sarahs_noise_file = '/Users/ashokan/osu/sarahspta/20yr_noisedict_rn+curn-bpl.json'
import json
with open(sarahs_noise_file,'r') as f:
    noise = json.load(f)
rn_psrs = noise
#print(rn_psrs)

#Nihan's noise dict for 15yr 
nihans_dict = '/Users/ashokan/osu/sarahspta/15yr_v1_fl_fwn_dict.json'
with open(nihans_dict,'r') as f:
    nihans_noise = json.load(f)

#NG20 real noise dict
ng20_noise_dict = '/Users/ashokan/osu/sarahspta/ng20_v1p1_dmx_noise_dict.json'
#from https://drive.google.com/drive/folders/1GQXnpyRglqPHwgQs6vE8VK-6VoL9WbSj
with open(ng20_noise_dict,'r') as f:
    ng20_noise_real = json.load(f)

#make a new noise dict with only chime and vegas pulsars
chime_vegas_noise_dict = {}
for k, v in ng20_noise_real.items():
    new_key = k.replace("t2equad", "equad")
    if "CHIME" in k or "YUPPI" in k or "VEGAS" in k or "J0125-2327" in k or "J0154+1833" in k or "J0614-3329" in k or "J0621+2514" in k or "J0732+2314" in k or "J0751+1807" in k or "J1022+1001" in k or "J1803+1358" in k or "J2022+2534" in k or "J2039-3616" in k or "J2150-0326" in k:
        print(k)
        chime_vegas_noise_dict[new_key] = v

#update nihans noise dict with chime and vegas pulsars from ng20
nihans_noise.update(chime_vegas_noise_dict)
# Out:
# B1855+09_CHIME_efac
# B1855+09_CHIME_log10_ecorr
# B1855+09_CHIME_log10_t2equad
# B1855+09_Rcvr1_2_VEGAS_efac
# B1855+09_Rcvr1_2_VEGAS_log10_ecorr
# B1855+09_Rcvr1_2_VEGAS_log10_t2equad
# B1937+21_3GHz_YUPPI_efac
# B1937+21_3GHz_YUPPI_log10_ecorr
# B1937+21_3GHz_YUPPI_log10_t2equad
# B1937+21_CHIME_efac
# B1937+21_CHIME_log10_ecorr
# B1937+21_CHIME_log10_t2equad
# B1937+21_Rcvr1_2_VEGAS_efac
# B1937+21_Rcvr1_2_VEGAS_log10_ecorr
# B1937+21_Rcvr1_2_VEGAS_log10_t2equad
# B1937+21_Rcvr_800_VEGAS_efac
# B1937+21_Rcvr_800_VEGAS_log10_ecorr
# B1937+21_Rcvr_800_VEGAS_log10_t2equad
# B1953+29_CHIME_efac
# B1953+29_CHIME_log10_ecorr
# B1953+29_CHIME_log10_t2equad
# J0023+0923_CHIME_efac
# J0023+0923_CHIME_log10_ecorr
# J0023+0923_CHIME_log10_t2equad
# J0023+0923_Rcvr1_2_VEGAS_efac
# J0023+0923_Rcvr1_2_VEGAS_log10_ecorr
# J0023+0923_Rcvr1_2_VEGAS_log10_t2equad
# J0030+0451_CHIME_efac
# J0030+0451_CHIME_log10_ecorr
# J0030+0451_CHIME_log10_t2equad
# J0030+0451_Rcvr1_2_VEGAS_efac
# J0030+0451_Rcvr1_2_VEGAS_log10_ecorr
# J0030+0451_Rcvr1_2_VEGAS_log10_t2equad
# J0102+4839_CHIME_efac
# J0102+4839_CHIME_log10_ecorr
# J0102+4839_CHIME_log10_t2equad
# J0125-2327_3GHz_YUPPI_efac
# J0125-2327_3GHz_YUPPI_log10_ecorr
# J1614-2230_Rcvr_800_VEGAS_log10_ecorr
# J1614-2230_Rcvr_800_VEGAS_log10_t2equad
# J1630+3734_CHIME_efac
# J1630+3734_CHIME_log10_ecorr
# J1630+3734_CHIME_log10_t2equad
# J1630+3734_Rcvr1_2_VEGAS_efac
# J1630+3734_Rcvr1_2_VEGAS_log10_ecorr
# J1630+3734_Rcvr1_2_VEGAS_log10_t2equad
# J1630+3734_Rcvr_800_VEGAS_efac
# J1630+3734_Rcvr_800_VEGAS_log10_ecorr
# J1630+3734_Rcvr_800_VEGAS_log10_t2equad
# J1640+2224_CHIME_efac
# J1640+2224_CHIME_log10_ecorr
# J1640+2224_CHIME_log10_t2equad
# J1640+2224_Rcvr1_2_VEGAS_efac
# J1640+2224_Rcvr1_2_VEGAS_log10_ecorr
# J1640+2224_Rcvr1_2_VEGAS_log10_t2equad
# J1643-1224_3GHz_YUPPI_efac
# J1643-1224_3GHz_YUPPI_log10_ecorr
# J1643-1224_3GHz_YUPPI_log10_t2equad
# J1643-1224_CHIME_efac
# J1643-1224_CHIME_log10_ecorr
# J1643-1224_CHIME_log10_t2equad
# J1643-1224_Rcvr1_2_VEGAS_efac
# J1643-1224_Rcvr1_2_VEGAS_log10_ecorr
# J1643-1224_Rcvr1_2_VEGAS_log10_t2equad
# J1643-1224_Rcvr_800_VEGAS_efac
# J1643-1224_Rcvr_800_VEGAS_log10_ecorr
# J1643-1224_Rcvr_800_VEGAS_log10_t2equad
# J1705-1903_3GHz_YUPPI_efac
# J1705-1903_3GHz_YUPPI_log10_ecorr
# J1705-1903_3GHz_YUPPI_log10_t2equad
# J1705-1903_Rcvr1_2_VEGAS_efac
# J1705-1903_Rcvr1_2_VEGAS_log10_ecorr
# J1705-1903_Rcvr1_2_VEGAS_log10_t2equad
# J1705-1903_Rcvr_800_VEGAS_efac
# J1705-1903_Rcvr_800_VEGAS_log10_ecorr
# J1705-1903_Rcvr_800_VEGAS_log10_t2equad
# J1713+0747_1.5GHz_YUPPI_efac
# J1713+0747_1.5GHz_YUPPI_log10_ecorr
# J1713+0747_1.5GHz_YUPPI_log10_t2equad
# J1713+0747_3GHz_YUPPI_efac
# J1713+0747_3GHz_YUPPI_log10_ecorr
# J1713+0747_3GHz_YUPPI_log10_t2equad
# J1713+0747_CHIME_efac
# J1713+0747_CHIME_log10_ecorr
# J1713+0747_CHIME_log10_t2equad
# J1713+0747_Rcvr1_2_VEGAS_efac
# J1713+0747_Rcvr1_2_VEGAS_log10_ecorr
# J1713+0747_Rcvr1_2_VEGAS_log10_t2equad
# J1713+0747_Rcvr_800_VEGAS_efac
# J1713+0747_Rcvr_800_VEGAS_log10_ecorr
# J1713+0747_Rcvr_800_VEGAS_log10_t2equad
# J1719-1438_Rcvr1_2_VEGAS_efac
# J1719-1438_Rcvr1_2_VEGAS_log10_ecorr
# J1719-1438_Rcvr1_2_VEGAS_log10_t2equad
# J1719-1438_Rcvr_800_VEGAS_efac
# J1719-1438_Rcvr_800_VEGAS_log10_ecorr
# J1802-2124_Rcvr_800_VEGAS_log10_t2equad
# J1803+1358_CHIME_efac
# J1803+1358_CHIME_log10_ecorr
# J1803+1358_CHIME_log10_t2equad
# J1803+1358_L-wide_PUPPI_efac
# J1803+1358_L-wide_PUPPI_log10_ecorr
# J1803+1358_L-wide_PUPPI_log10_t2equad
# J1803+1358_Rcvr1_2_VEGAS_efac
# J1803+1358_Rcvr1_2_VEGAS_log10_ecorr
# J1803+1358_Rcvr1_2_VEGAS_log10_t2equad
# J1803+1358_red_noise_gamma
# J1803+1358_red_noise_log10_A
# J1811-2405_Rcvr1_2_VEGAS_efac
# J1811-2405_Rcvr1_2_VEGAS_log10_ecorr
# J1811-2405_Rcvr1_2_VEGAS_log10_t2equad
# J1811-2405_Rcvr_800_VEGAS_efac
# J1811-2405_Rcvr_800_VEGAS_log10_ecorr
# J1811-2405_Rcvr_800_VEGAS_log10_t2equad
# J1832-0836_Rcvr1_2_VEGAS_efac
# J1832-0836_Rcvr1_2_VEGAS_log10_ecorr
# J1832-0836_Rcvr1_2_VEGAS_log10_t2equad
# J1832-0836_Rcvr_800_VEGAS_efac
# J1832-0836_Rcvr_800_VEGAS_log10_ecorr
# J1832-0836_Rcvr_800_VEGAS_log10_t2equad
# J1843-1113_Rcvr1_2_VEGAS_efac
# J1843-1113_Rcvr1_2_VEGAS_log10_ecorr
# J1843-1113_Rcvr1_2_VEGAS_log10_t2equad
# J1843-1113_Rcvr_800_VEGAS_efac
# J1843-1113_Rcvr_800_VEGAS_log10_ecorr
# J1843-1113_Rcvr_800_VEGAS_log10_t2equad
# J1853+1303_CHIME_efac
# J1853+1303_CHIME_log10_ecorr
# J1853+1303_CHIME_log10_t2equad
# J1853+1303_Rcvr1_2_VEGAS_efac
# J1853+1303_Rcvr1_2_VEGAS_log10_ecorr
# J1853+1303_Rcvr1_2_VEGAS_log10_t2equad
# J1903+0327_3GHz_YUPPI_efac
# J1903+0327_3GHz_YUPPI_log10_ecorr
# J1903+0327_3GHz_YUPPI_log10_t2equad
# J1903+0327_Rcvr1_2_VEGAS_efac
# J1903+0327_Rcvr1_2_VEGAS_log10_ecorr
# J1903+0327_Rcvr1_2_VEGAS_log10_t2equad
# J1909-3744_3GHz_YUPPI_efac
# J1909-3744_3GHz_YUPPI_log10_ecorr
# J1909-3744_3GHz_YUPPI_log10_t2equad
# J1909-3744_Rcvr1_2_VEGAS_efac
# J1909-3744_Rcvr1_2_VEGAS_log10_ecorr
# J1909-3744_Rcvr1_2_VEGAS_log10_t2equad
# J1909-3744_Rcvr_800_VEGAS_efac
# J1909-3744_Rcvr_800_VEGAS_log10_ecorr
# J1909-3744_Rcvr_800_VEGAS_log10_t2equad
# J1910+1256_Rcvr1_2_VEGAS_efac
# J1910+1256_Rcvr1_2_VEGAS_log10_ecorr
# J1910+1256_Rcvr1_2_VEGAS_log10_t2equad
# J1911+1347_CHIME_efac
# J1911+1347_CHIME_log10_ecorr
# J1911+1347_CHIME_log10_t2equad
# J2150-0326_Rcvr_800_VEGAS_log10_ecorr
# J2150-0326_Rcvr_800_VEGAS_log10_t2equad
# J2150-0326_red_noise_gamma
# J2150-0326_red_noise_log10_A
# J2214+3000_3GHz_YUPPI_efac
# J2214+3000_3GHz_YUPPI_log10_ecorr
# J2214+3000_3GHz_YUPPI_log10_t2equad
# J2214+3000_CHIME_efac
# J2214+3000_CHIME_log10_ecorr
# J2214+3000_CHIME_log10_t2equad
# J2214+3000_Rcvr1_2_VEGAS_efac
# J2214+3000_Rcvr1_2_VEGAS_log10_ecorr
# J2214+3000_Rcvr1_2_VEGAS_log10_t2equad
# J2229+2643_CHIME_efac
# J2229+2643_CHIME_log10_ecorr
# J2229+2643_CHIME_log10_t2equad
# J2229+2643_Rcvr1_2_VEGAS_efac
# J2229+2643_Rcvr1_2_VEGAS_log10_ecorr
# J2229+2643_Rcvr1_2_VEGAS_log10_t2equad
# J2234+0611_CHIME_efac
# J2234+0611_CHIME_log10_ecorr
# J2234+0611_CHIME_log10_t2equad
# J2234+0611_Rcvr1_2_VEGAS_efac
# J2234+0611_Rcvr1_2_VEGAS_log10_ecorr
# J2234+0611_Rcvr1_2_VEGAS_log10_t2equad
# J2234+0944_CHIME_efac
# J2234+0944_CHIME_log10_ecorr
# J2234+0944_CHIME_log10_t2equad
# J2234+0944_Rcvr1_2_VEGAS_efac
# J2234+0944_Rcvr1_2_VEGAS_log10_ecorr
# J2234+0944_Rcvr1_2_VEGAS_log10_t2equad
# J2302+4442_CHIME_efac
# J2302+4442_CHIME_log10_ecorr
# J2302+4442_CHIME_log10_t2equad
# J2302+4442_Rcvr1_2_VEGAS_efac
# J2302+4442_Rcvr1_2_VEGAS_log10_ecorr
# J2302+4442_Rcvr1_2_VEGAS_log10_t2equad
# J2302+4442_Rcvr_800_VEGAS_efac
# J2302+4442_Rcvr_800_VEGAS_log10_ecorr
# J2302+4442_Rcvr_800_VEGAS_log10_t2equad
# J2317+1439_CHIME_efac
# J2317+1439_CHIME_log10_ecorr
# J2317+1439_CHIME_log10_t2equad
# J2317+1439_Rcvr1_2_VEGAS_efac
# J2317+1439_Rcvr1_2_VEGAS_log10_ecorr
# J2317+1439_Rcvr1_2_VEGAS_log10_t2equad
# J2322+2057_CHIME_efac
# J2322+2057_CHIME_log10_ecorr
# J2322+2057_CHIME_log10_t2equad
# J2322+2057_Rcvr1_2_VEGAS_efac
# J2322+2057_Rcvr1_2_VEGAS_log10_ecorr
# J2322+2057_Rcvr1_2_VEGAS_log10_t2equad

# %%
def make_corr(psr,noise):
    N = psr.toaerrs.size
    corr = np.zeros((N,N))
    _, _, fl, _, bi = hsen.quantize_fast(psr.toas,psr.toaerrs,
                                         flags=psr.flags['f'],dt=1)
    keys = [ky for ky in noise.keys() if psr.name in ky]
    backends = np.unique(psr.flags['f'])
    sigma_sqr = np.zeros(N)
    ecorrs = np.zeros_like(fl,dtype=float)
    for be in backends:
        mask = np.where(psr.flags['f']==be)
        key_ef = '{0}_{1}_{2}'.format(psr.name,be,'efac')
        key_eq = '{0}_{1}_log10_{2}'.format(psr.name,be,'equad')
        key_ec = '{0}_{1}_log10_{2}'.format(psr.name,be,'ecorr')
        sigma_sqr[mask] = (noise[key_ef]**2 * ((psr.toaerrs[mask]**2)
                           + (10**noise[key_eq])**2)+(10**noise[key_ec])**2)
        mask_ec = np.where(fl==be)
        key_ec = '{0}_{1}_log10_{2}'.format(psr.name,be,'ecorr')
        ecorrs[mask_ec] = np.ones_like(mask_ec) * (10**noise[key_ec])
    j = [ecorrs[ii]**2*np.ones((len(bucket),len(bucket)))
         for ii, bucket in enumerate(bi)]

    J = sl.block_diag(*j)
    corr = np.diag(sigma_sqr) + J
    return corr

# %%
#make correlation matrix with only toaerrs for Sarah's data
def make_corr_our(psr):
    sigma_sqrt = psr.toaerrs**2
    corr = np.diag(sigma_sqrt)
    return corr

# %%
Tspan = hsen.get_Tspan(ePsrs)
fyr = 1/(365.25*24*3600)
freqs = np.logspace(np.log10(1/(5*Tspan)),np.log10(2e-7),600)

# %%
#make hasasia pulsars from enterprise pulsars.
A_gwb, gamma_gwb = 6.4e-15, 3.2 # median values from detection paper
psrs = []
thin = 1
for ePsr in ePsrs:
    corr = make_corr_our(ePsr)[::thin,::thin]
    nihans_corr = make_corr(ePsr,nihans_noise)
    plaw = hsen.red_noise_powerlaw(A=A_gwb, gamma=gamma_gwb, freqs=freqs)
    if ePsr.name in rn_psrs.keys():
        Amp, gam = rn_psrs[ePsr.name]
        plaw += hsen.red_noise_powerlaw(A=10**Amp, gamma=gam, freqs=freqs)

    nihans_corr += hsen.corr_from_psd(freqs=freqs, psd=plaw,
                               toas=ePsr.toas[::thin])
    psr = hsen.Pulsar(toas=ePsr.toas[::thin],
                      toaerrs=ePsr.toaerrs[::thin],
                      phi=ePsr.phi,theta=ePsr.theta,
                      N=nihans_corr, designmatrix=ePsr.Mmat[::thin,:])
    psr.name = ePsr.name
    psrs.append(psr)
    del ePsr
    print('\rPSR {0} complete'.format(psr.name),end='',flush=True)
# Out:
# PSR J2322+2057 complete

# %%
#make spectra
specs = []
for p in psrs:
    sp = hsen.Spectrum(p, freqs=freqs,amp_gw=None, gamma_gw=None)
    _ = sp.NcalInv
    specs.append(sp)
    print('\rPSR {0} complete'.format(p.name),end='',flush=True)
ng20_sarah_nihans_wn = hsen.GWBSensitivityCurve(specs)
# Out:
# PSR J2322+2057 complete

# %%
#plot against original NG15 curve
ng15_pkl_gwb = '/Users/ashokan/osu/sarahspta/ng15yr_v1p1_pint_logf_m2a_red_noise_vg_gwbsc.has' 
with open (ng15_pkl_gwb,'rb') as f:
    ng15_sc_gwb = pickle.load(f)

plt.loglog(ng20_sarah_nihans_wn.freqs,ng20_sarah_nihans_wn.h_c,label='NANOGrav 20-yr with Nihan\'s WN')
plt.loglog(ng15_sc_gwb.freqs,ng15_sc_gwb.h_c,label='NANOGrav 15-yr')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Characteristic Strain, $h_c$')
plt.title('NANOGrav 20-15-year Data Set Sensitivity Curve')
plt.grid(which='both')
# plt.ylim(1e-15,9e-12)
plt.legend()
plt.show()

# %%
#SNR of full NG20 data now
alpha_gwb = (3. - gamma_gwb) / 2.
S_h = hsen.S_h(A=A_gwb, alpha=alpha_gwb, freqs=freqs)
snr_20 = ng20_sarah_nihans_wn.SNR(S_h)
print(snr_20)
# Out:
# 9.270893705444763

# %% [markdown]
# Okay that is how the full NG20 dataset from Sarah looks like in comparison to NG15. Now lets slice it to 15 year.

# %%
def get_sliced_spectra(psrs, 
                       start_mjd=1,
                       end_mjd = None,
                       ):
    """
    Parameters 
    ----------
    
    psrs : list of enterprise.Pulsar or list of hasasia.Pulsar objects
        List of enterprise/hasasia Pulsar objects
        
    cutoff : float
        MJD cutoff for the calculation
    
    sigma_correction : ?
        ???
    """
    psrs_cut = []
    psrs_copy = copy.deepcopy(psrs)
    for idx, psr in enumerate(psrs_copy):
        # filter the data around to the appropriate slice
        #print("N_toa = ", len(psr.toas))
        psr.filter_data(start_time=start_mjd, end_time=end_mjd)
        #print("after filter = ", len(psr.toas)) 
        # If there are no TOAs remaining, or the time span of the pulsar is <3 cut.
        if (psr.toas.size == 0) or (hsen.get_Tspan([psr]) < 3*365.25*24*3600):
            #idxs.append(idx)
           pass
        else:
            psrs_cut.append(psr)
    timespan = hsen.get_Tspan(psrs_cut)
    spectra = []
    for idx, p in enumerate(psrs_cut):
        sp = hsen.Spectrum(p, freqs=freqs,amp_gw=None, gamma_gw=None)
        sp.name = p.name
        _ = sp.NcalInv
        #print(f"psr spectra {idx} is done")
        spectra.append(sp)
    print(f"PTA spectrum with {len(spectra)} psrs created.")
    return spectra

# %%
end_mjd = 59033
psr_spectra = get_sliced_spectra(psrs, 
                       start_mjd=1,
                       end_mjd = end_mjd,
                       )
# Out:
# PTA spectrum with 64 psrs created.

# %%
#SNR of sliced data
sliced_GWBSC = hsen.GWBSensitivityCurve(spectra=psr_spectra, orf='hd', autocorr=False)
S_h = hsen.S_h(A=A_gwb, alpha=alpha_gwb, freqs=freqs)
sliced_SNR = sliced_GWBSC.SNR(S_h)
print(sliced_SNR)
# Out:
# 5.721630962725952

# %%
print(len(psrs))
print(len(psr_spectra)) #If there are no TOAs remaining or < 3 years of data pulsar gets left out
# Out:
# 77
# 64

# %%
#plot 15year slice of NG20 against NG15
plt.loglog(sliced_GWBSC.freqs,sliced_GWBSC.h_c,label='15year slice of NANOGrav 20-yr')
plt.loglog(ng15_sc_gwb.freqs,ng15_sc_gwb.h_c,label='NANOGrav 15-yr')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Characteristic Strain, $h_c$')
plt.title(
'NANOGrav Sensitivity Curves, tuned w 15year WN, SNR={:.2f}'.format(
    sliced_SNR
)
)

#plt.title('NANOGrav Sensitivity Curves, tuned with FACTOR={:.4f}'.format(FACTOR),'SNR={:.2f}'.format(sliced_with_factor_SNR))

plt.grid(which='both')
# plt.ylim(1e-15,9e-12)
plt.legend()
plt.show()

# %% [markdown]
# Okay this has an SNR of 5.7
# We want it to be 5 as was in the original NG15 analysis.

# %% [markdown]
# Lets tune its white noise.

# %% [markdown]
# We'll have to use enterprise pulsar objects and chop because hasasia pulsars have no flags etc and their ecorr equad etc become a pain to use in the expression for sigma^2

# %%
end_mjd = 59033
psrs_cut_NG15 = get_sliced_pulsars(psrs, 
                       start_mjd=1,
                       end_mjd = end_mjd,
                       )

# %%
#We tune by multiplying toaerrs by a FACTOR
def make_corr_our_tuning_with_all_wn(psr,noise,FACTOR=1.0):
    N = psr.toaerrs.size
    corr = np.zeros((N,N))
    _, _, fl, _, bi = hsen.quantize_fast(psr.toas,psr.toaerrs,
                                         flags=psr.flags['f'],dt=1)
    keys = [ky for ky in noise.keys() if psr.name in ky]
    backends = np.unique(psr.flags['f'])
    sigma_sqr = np.zeros(N)
    ecorrs = np.zeros_like(fl,dtype=float)
    for be in backends:
        mask = np.where(psr.flags['f']==be)
        key_ef = '{0}_{1}_{2}'.format(psr.name,be,'efac')
        key_eq = '{0}_{1}_log10_{2}'.format(psr.name,be,'equad')
        key_ec = '{0}_{1}_log10_{2}'.format(psr.name,be,'ecorr')
        sigma_sqr[mask] = (noise[key_ef]**2 * (FACTOR*(psr.toaerrs[mask]**2)
                           + (10**noise[key_eq])**2)+(10**noise[key_ec])**2)
        mask_ec = np.where(fl==be)
        key_ec = '{0}_{1}_log10_{2}'.format(psr.name,be,'ecorr')
        ecorrs[mask_ec] = np.ones_like(mask_ec) * (10**noise[key_ec])
    j = [ecorrs[ii]**2*np.ones((len(bucket),len(bucket)))
         for ii, bucket in enumerate(bi)]

    J = sl.block_diag(*j)
    corr = np.diag(sigma_sqr) + J
    return corr

# %% [markdown]
# Lets try to chop enterprise pulsars instead of hasasia pulsars.

# %%
def get_sliced_epulsars(psrs, 
                       start_mjd=1,
                       end_mjd = None,
                       ):
    """
    Parameters 
    ----------
    
    psrs : list of enterprise.Pulsar or list of hasasia.Pulsar objects
        List of enterprise/hasasia Pulsar objects

    start_mjd : float
        MJD start time for the calculation

    end_mjd : float
        MJD end time for the calculation
    """
    psrs_cut = []
    psrs_copy = copy.deepcopy(psrs)
    for idx, psr in enumerate(psrs_copy):
        # filter the data around to the appropriate slice
        #print("N_toa = ", len(psr.toas))
        psr.filter_data(start_time=start_mjd, end_time=end_mjd)
        #print("after filter = ", len(psr.toas)) 
        # If there are no TOAs remaining, or the time span of the pulsar is <3 cut.
        if (psr.toas.size == 0) or (hsen.get_Tspan([psr]) < 3*365.25*24*3600):
    #         idxs.append(idx)
            pass
        else:
            psrs_cut.append(psr)
    return psrs_cut

# %%
end_mjd = 59033
epsrs_cut_NG15 = get_sliced_epulsars(ePsrs, 
                       start_mjd=1,
                       end_mjd = end_mjd,
                       )

# %%
print(len(ePsrs))
print(len(epsrs_cut_NG15)) #once again if no TOAs or < 3 years of data pulsar gets left out
# Out:
# 77
# 64

# %% [markdown]
# ## Loop over prefactors

# %%
sliced_15yr_SNRS = []
for prefactor in [0.5,0.6,0.7,2]:
    FACTOR = prefactor*1.45*np.sqrt(np.pi)
    print("FACTOR = ", FACTOR)    
    A_gwb, gamma_gwb = 6.4e-15, 3.2 # median values from detection paper
    psrs = []
    thin = 1
    for ePsr in epsrs_cut_NG15:
        nihans_corr = make_corr_our_tuning_with_all_wn(ePsr,nihans_noise,FACTOR=FACTOR)
        plaw = hsen.red_noise_powerlaw(A=A_gwb, gamma=gamma_gwb, freqs=freqs)
        if ePsr.name in rn_psrs.keys():
            Amp, gam = rn_psrs[ePsr.name]
            plaw += hsen.red_noise_powerlaw(A=10**Amp, gamma=gam, freqs=freqs)

        nihans_corr += hsen.corr_from_psd(freqs=freqs, psd=plaw,
                                toas=ePsr.toas[::thin])
        psr = hsen.Pulsar(toas=ePsr.toas[::thin],
                        toaerrs=ePsr.toaerrs[::thin],
                        phi=ePsr.phi,theta=ePsr.theta,
                        N=nihans_corr, designmatrix=ePsr.Mmat[::thin,:])
        psr.name = ePsr.name
        psrs.append(psr)
        del ePsr
    print('\rPSR {0} complete'.format(psr.name),end='',flush=True)

    specs = []
    for p in psrs:
        sp = hsen.Spectrum(p, freqs=freqs,amp_gw=None, gamma_gw=None)
        _ = sp.NcalInv
        specs.append(sp)
        #print('\rPSR {0} complete'.format(p.name),end='',flush=True)

    ng20_sarah_sc_with_factor = hsen.GWBSensitivityCurve(specs)
    sliced_with_factor_SNR = ng20_sarah_sc_with_factor.SNR(S_h)
    sliced_15yr_SNRS.append(sliced_with_factor_SNR)
    print("sliced_with_factor_SNR = ", sliced_with_factor_SNR)

    plt.loglog(ng20_sarah_sc_with_factor.freqs,ng20_sarah_sc_with_factor.h_c,label='15year slice of NANOGrav 20-yr')
    plt.loglog(ng15_sc_gwb.freqs,ng15_sc_gwb.h_c,label='NANOGrav 15-yr')
    plt.xlabel('Frequency [Hz]')
    plt.ylabel('Characteristic Strain, $h_c$')
    plt.title(
    'NANOGrav Sensitivity Curves, tuned with FACTOR={:.4f}, SNR={:.2f}'.format(
        FACTOR, sliced_with_factor_SNR
    )
)
    #plt.title('NANOGrav 20-15-year Data Set Sensitivity Curve, tuned with FACTOR={0}'.format(FACTOR))
    plt.grid(which='both')
    # plt.ylim(1e-15,9e-12)
    plt.legend()
    plt.show()
# Out:
# FACTOR =  1.285029041906499
# PSR J2322+2057 completesliced_with_factor_SNR =  5.258451785440382
# FACTOR =  1.5420348502877987
# PSR J2322+2057 completesliced_with_factor_SNR =  5.033700917533949
# FACTOR =  1.7990406586690983
# PSR J2322+2057 completesliced_with_factor_SNR =  4.842038163709898
# FACTOR =  5.140116167625996
# PSR J2322+2057 completesliced_with_factor_SNR =  3.5354203046276735

# %% [markdown]
# The last one is just to show that the sensitivity curve is being affected by the factor although it might not seem like it with the first three values of factor!

# %% [markdown]
# ### So to conclude, if you use a factor of 1.5420348502877987 on toaerror, and use the noise dict formed by the combination of 15year WN + (CHIME, VEGAS, extra pulsars) from real NG20, then you will get an SNR of 5 on the NG15 slice of the simulated NG20 dataset.
