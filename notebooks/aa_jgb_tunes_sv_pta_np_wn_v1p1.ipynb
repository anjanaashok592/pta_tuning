# %%
import pickle, copy, json
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = False
import matplotlib.patches as mpatches
import matplotlib.ticker as ticker
import matplotlib as mpl
import matplotlib.cm as cm
import scipy.stats as sps
from random import shuffle
import itertools

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
#import la_forge.utils as lf_utils
#lf_utils.set_publication_params({'text.usetex':False})
#fig_dir = '/home/baierj/projects/hasasia2/hasasia2_paper/figures'

# %%
import healpy as hp
import astropy.units as u
import astropy.constants as c
from astropy.coordinates import SkyCoord
#import plot #Script originally written by Leo Stein for making pretty sky maps. 

# Setting various healpy quantities and GW source sky positions.
NSIDE = 8
NPIX = hp.nside2npix(NSIDE)
IPIX = np.arange(NPIX)
theta_gw, phi_gw = hp.pix2ang(nside=NSIDE,ipix=IPIX)

# %%
import numpy as np
import scipy.linalg as sl
import matplotlib.pyplot as plt
# %matplotlib inline
import glob, pickle, json
import hasasia.sensitivity as hsen
import hasasia.sim as hsim
import hasasia.skymap as hsky
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300
mpl.rcParams['figure.figsize'] = [5,3]
mpl.rcParams['text.usetex'] = True
from enterprise.pulsar import Pulsar as ePulsar

# %%
#get v1p1
ng20_irn = '/Users/ashokan/osu/sarahspta/data/NG20v1p1_irn_with_EF_EQ_factor/'
pardir = ng20_irn
timdir = ng20_irn
pars = sorted(glob.glob(pardir+'*.par'))
tims = sorted(glob.glob(timdir+'*.tim'))

# %%
#check number of pulsars
print(len(pars))
print(len(tims))
# Out:
# 80
# 80

# %%
#check first par and tim files
print(pars[0])
print(tims[0])
# Out:
# /Users/ashokan/osu/sarahspta/data/NG20v1p1_irn_with_EF_EQ_factor/B1855+09.par
# /Users/ashokan/osu/sarahspta/data/NG20v1p1_irn_with_EF_EQ_factor/B1855+09.tim

# %%
#make enterprise pulsars
ePsrs = []
for par,tim in zip(pars,tims):
    # if 'J1802' in par:
    #     continue #this pulsar has some issue
    #else:
    ePsr = ePulsar(par, tim,  ephem='DE440')
    ePsrs.append(ePsr)
    print('\rPSR {0} complete'.format(ePsr.name),end='',flush=True)
# Out:
# 2025-10-10 20:13:25.381 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2023 from the given model
# 2025-10-10 20:13:25.505 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-10 20:13:25.508 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-10 20:13:25.517 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:25.518 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:25.519 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-10 20:13:25.578 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:25.579 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:25.580 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-10 20:13:25.673 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:25.674 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:25.675 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='gbt'.
# 2025-10-10 20:13:25.681 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-10 20:13:25.682 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-10 20:13:25.731 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-10 20:13:25.732 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-10 20:13:25.736 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.755 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [5.39316141e+09 1.34911428e+11 5.84771576e+10] m
# 2025-10-10 20:13:25.756 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.757 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.757 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.759 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.760 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.760 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.761 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.770 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.805 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-7.93797492e+09 -1.38231720e+11 -5.99234428e+10] m
# 2025-10-10 20:13:25.805 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.806 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.807 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.808 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.809 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.810 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.811 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.813 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.817 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.48209377e+11  2.02008500e+10  8.78368581e+09] m
# 2025-10-10 20:13:25.819 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.819 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.820 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.820 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.821 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.822 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.822 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.823 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-10 20:13:25.863 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.897 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.931 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.937 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-10 20:13:25.937 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:25.939 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:25.970 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:25.971 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:25.980 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-10-10 20:13:25.982 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-10 20:13:25.982 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-10 20:13:25.983 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:25.984 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:25.984 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-10 20:13:25.985 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-10 20:13:25.986 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-10 20:13:25.987 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-10 20:13:25.987 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.992 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.49328670e+11  6.35100491e+09  2.76121816e+09] m
# 2025-10-10 20:13:25.993 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.994 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.995 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.997 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.997 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.998 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:25.999 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:26.000 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-10 20:13:26.001 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-10 20:13:26.030 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:26.033 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-10 20:13:26.034 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.035 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.082 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.084 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.123 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.124 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.168 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.170 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.223 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.224 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.267 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.268 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.314 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.316 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.362 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.368 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.418 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.421 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.465 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.471 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.533 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.535 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.582 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.583 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.600 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.639 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:26.641 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR B1855+09 complete
# 2025-10-10 20:13:26.717 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2023 from the given model
# 2025-10-10 20:13:26.937 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-10 20:13:26.942 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-10 20:13:26.953 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:26.954 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:26.954 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-10 20:13:27.016 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:27.017 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:27.018 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-10 20:13:27.170 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:27.171 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:27.172 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='gbt'.
# 2025-10-10 20:13:27.241 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:27.242 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:27.243 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='vla'.
# 2025-10-10 20:13:27.253 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-10 20:13:27.254 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-10 20:13:27.348 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-10 20:13:27.349 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-10 20:13:27.352 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.368 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.28737896e+11  6.57547883e+10  2.84933842e+10] m
# 2025-10-10 20:13:27.369 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.370 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.372 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.373 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.375 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.376 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.378 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.389 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.424 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.19025283e+11 -8.39382759e+10 -3.63876674e+10] m
# 2025-10-10 20:13:27.425 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.427 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.429 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.430 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.431 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.433 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.434 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.440 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.467 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 1.50622009e+11 -8.40559413e+09 -3.65554206e+09] m
# 2025-10-10 20:13:27.467 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.470 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.471 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.473 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.476 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.478 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.479 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.481 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.487 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [1.43321436e+11 3.54856657e+10 1.54134189e+10] m
# 2025-10-10 20:13:27.488 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.489 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.490 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.491 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.492 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.492 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.493 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.494 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-10 20:13:27.539 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.564 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.610 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.641 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.646 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-10 20:13:27.647 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:27.650 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:27.683 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:27.686 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:27.693 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-10-10 20:13:27.695 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-10 20:13:27.695 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-10 20:13:27.697 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:27.698 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:27.699 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='gbt'.
# 2025-10-10 20:13:27.700 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-10 20:13:27.701 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-10 20:13:27.703 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-10 20:13:27.705 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.709 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.35098730e+11  5.68380011e+10  2.46490991e+10] m
# 2025-10-10 20:13:27.710 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.710 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.711 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.711 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.712 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.714 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.714 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.715 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-10 20:13:27.717 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-10 20:13:27.744 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:27.747 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-10 20:13:27.749 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:27.750 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:27.808 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:27.810 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:27.840 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:27.842 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:27.906 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:27.910 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:27.951 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:27.953 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.005 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.006 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.051 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.053 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.071 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.106 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.108 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR B1937+21 complete
# 2025-10-10 20:13:28.202 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2023 from the given model
# 2025-10-10 20:13:28.323 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-10 20:13:28.326 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-10 20:13:28.336 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:28.338 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:28.338 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-10 20:13:28.405 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:28.407 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:28.409 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-10 20:13:28.494 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-10 20:13:28.494 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-10 20:13:28.526 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-10 20:13:28.527 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-10 20:13:28.531 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.551 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 6.39615815e+10 -1.26375641e+11 -5.47812334e+10] m
# 2025-10-10 20:13:28.551 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.553 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.555 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.556 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.558 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.559 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.561 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.566 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.589 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.19388263e+11 -8.35025455e+10 -3.61964919e+10] m
# 2025-10-10 20:13:28.590 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.591 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.592 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.592 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.595 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.596 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.597 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.599 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-10 20:13:28.653 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.677 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.705 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-10 20:13:28.705 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.707 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.741 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.742 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.759 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-10-10 20:13:28.762 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-10 20:13:28.762 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-10 20:13:28.764 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:28.765 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:28.766 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-10 20:13:28.769 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-10 20:13:28.769 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-10 20:13:28.772 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-10 20:13:28.774 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.777 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 4.17618730e+10 -1.34483104e+11 -5.83157546e+10] m
# 2025-10-10 20:13:28.778 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.779 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.779 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.781 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.782 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.783 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.784 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.785 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-10 20:13:28.786 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-10 20:13:28.825 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:28.829 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-10 20:13:28.830 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.831 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.889 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.890 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.933 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:28.935 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.011 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.013 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.070 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.072 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.120 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.121 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.193 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.195 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.249 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.252 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.312 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.314 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.360 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.363 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.405 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.406 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.452 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.454 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.504 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.506 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.527 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.565 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:29.567 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR B1953+29 complete
# 2025-10-10 20:13:29.621 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2023 from the given model
# 2025-10-10 20:13:30.136 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-10 20:13:30.139 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-10 20:13:30.144 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:30.145 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:30.145 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-10 20:13:30.189 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:30.191 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:30.192 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-10 20:13:30.321 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:30.322 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:30.323 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='gbt'.
# 2025-10-10 20:13:30.328 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-10 20:13:30.328 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-10 20:13:30.380 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-10 20:13:30.381 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-10 20:13:30.384 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.395 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.42573928e+11  3.86926049e+10  1.67754082e+10] m
# 2025-10-10 20:13:30.396 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.397 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.398 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.399 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.400 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.402 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.402 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.416 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.463 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 1.08241462e+11 -9.60944106e+10 -4.16553595e+10] m
# 2025-10-10 20:13:30.464 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.466 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.467 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.468 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.469 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.470 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.471 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.473 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.477 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.49334981e+11  1.22473747e+10  5.33256030e+09] m
# 2025-10-10 20:13:30.478 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.479 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.479 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.480 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.481 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.482 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.482 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.483 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-10 20:13:30.519 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.541 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.585 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.590 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-10 20:13:30.590 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:30.592 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:30.620 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:30.622 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:13:30.632 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-10-10 20:13:30.634 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-10 20:13:30.635 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-10 20:13:30.637 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:13:30.638 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:13:30.638 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-10 20:13:30.640 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-10 20:13:30.640 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-10 20:13:30.642 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-10 20:13:30.644 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.647 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [ 5.87710243e+10 -1.29005528e+11 -5.59435250e+10] m
# 2025-10-10 20:13:30.648 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.649 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.650 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.651 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.652 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.652 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.653 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.653 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-10 20:13:30.654 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-10 20:13:30.677 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:13:30.684 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# ...
# 2025-10-10 20:14:59.053 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-10 20:14:59.054 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-10 20:14:59.078 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:14:59.082 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-10 20:14:59.083 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.084 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.134 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.136 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.167 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.169 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.216 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.218 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.269 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.271 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.322 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.325 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.383 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.385 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.442 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.444 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.504 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.507 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.565 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.566 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.614 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.616 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.669 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.670 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.716 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.718 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.738 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.771 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:14:59.772 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR J2317+1439 complete
# 2025-10-10 20:14:59.853 | DEBUG    | pint.toa:get_TOAs:211 - Using CLOCK = BIPM2023 from the given model
# 2025-10-10 20:15:00.119 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-10 20:15:00.120 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-10 20:15:00.124 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:15:00.125 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:15:00.126 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-10 20:15:00.168 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:15:00.169 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:15:00.170 | INFO     | pint.observatory.topo_obs:clock_corrections:354 - Observatory chime requires no clock corrections.
# 2025-10-10 20:15:00.220 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:15:00.221 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:15:00.222 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='gbt'.
# 2025-10-10 20:15:00.228 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-10 20:15:00.229 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-10 20:15:00.254 | DEBUG    | pint.toa:get_TOAs:310 - Planet PosVels will be calculated.
# 2025-10-10 20:15:00.254 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-10 20:15:00.256 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.265 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.32090790e+11  6.03101032e+10  2.61245816e+10] m
# 2025-10-10 20:15:00.266 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.266 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.267 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.267 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.268 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.268 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.269 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.273 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.293 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.18404074e+11 -8.46988267e+10 -3.67168762e+10] m
# 2025-10-10 20:15:00.294 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.295 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.297 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.298 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.299 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.300 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.302 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.304 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.308 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-1.47905662e+11  2.18445975e+10  9.49398036e+09] m
# 2025-10-10 20:15:00.309 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.310 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.310 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.311 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.311 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.312 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.312 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.313 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-10 20:15:00.353 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.366 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.385 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.389 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-10 20:15:00.390 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.391 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.431 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.432 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.435 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:101 - Creating and dealing with the single TZR_toa for absolute phase
# 2025-10-10 20:15:00.436 | DEBUG    | pint.toa:__init__:1377 - No pulse number flags found in the TOAs
# 2025-10-10 20:15:00.437 | DEBUG    | pint.toa:apply_clock_corrections:2232 - Applying clock corrections (include_bipm = True)
# 2025-10-10 20:15:00.437 | INFO     | pint.observatory:gps_correction:230 - Applying GPS to UTC clock correction (~few nanoseconds)
# 2025-10-10 20:15:00.438 | INFO     | pint.observatory:bipm_correction:245 - Applying TT(TAI) to TT(BIPM2023) clock correction (~27 us)
# 2025-10-10 20:15:00.439 | INFO     | pint.observatory.topo_obs:clock_corrections:340 - Applying observatory clock corrections for observatory='arecibo'.
# 2025-10-10 20:15:00.439 | DEBUG    | pint.toa:compute_TDBs:2278 - Computing TDB columns.
# 2025-10-10 20:15:00.440 | DEBUG    | pint.toa:compute_TDBs:2299 - Using EPHEM = DE440 for TDB calculation.
# 2025-10-10 20:15:00.441 | DEBUG    | pint.toa:compute_posvels:2374 - Computing PosVels of observatories, Earth and planets, using DE440
# 2025-10-10 20:15:00.442 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.444 | DEBUG    | pint.toa:compute_posvels:2432 - SSB obs pos [-5.78605122e+10 -1.28021117e+11 -5.55223125e+10] m
# 2025-10-10 20:15:00.444 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.445 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.445 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.446 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.447 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.447 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.448 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.449 | DEBUG    | pint.toa:compute_posvels:2446 - Adding columns ssb_obs_pos ssb_obs_vel obs_sun_pos obs_jupiter_pos obs_saturn_pos obs_venus_pos obs_uranus_pos obs_neptune_pos obs_earth_pos
# 2025-10-10 20:15:00.449 | DEBUG    | pint.models.absolute_phase:get_TZR_toa:122 - Done with TZR_toa
# 2025-10-10 20:15:00.474 | INFO     | pint.solar_system_ephemerides:load_kernel:194 - Set solar system ephemeris to de440 through astropy
# 2025-10-10 20:15:00.477 | DEBUG    | pint.toa:add_vel_ecl:2496 - Adding column ssb_obs_vel_ecl
# 2025-10-10 20:15:00.478 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.479 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.521 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.522 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.565 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.567 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.614 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.616 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.661 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.662 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.708 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.711 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.764 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.765 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.781 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# WARNING: Could not find pulsar distance for PSR J2322+2057. Setting value to 1 with 20% uncertainty.
# 2025-10-10 20:15:00.810 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# 2025-10-10 20:15:00.812 | DEBUG    | pint.models.astrometry:ssb_to_psb_xyz_ECL:983 - ECL not specified; using IERS2010.
# PSR J2322+2057 complete

# %%
#make a noise dict that  works 

#sarah's noise file
sarahs_noise_file = '/Users/ashokan/osu/sarahspta/20yr_noisedict_rn+curn-bpl.json'
import json
with open(sarahs_noise_file,'r') as f:
    noise = json.load(f)
rn_psrs = noise
#print(rn_psrs)

#Nihan's noise dict for 15yr 
nihans_dict = '/Users/ashokan/osu/sarahspta/15yr_v1_fl_fwn_dict.json'
with open(nihans_dict,'r') as f:
    nihans_noise = json.load(f)

#NG20 real noise dict
ng20_noise_dict = '/Users/ashokan/osu/sarahspta/ng20_v1p1_dmx_noise_dict.json'
#from https://drive.google.com/drive/folders/1GQXnpyRglqPHwgQs6vE8VK-6VoL9WbSj
with open(ng20_noise_dict,'r') as f:
    ng20_noise_real = json.load(f)

#make a new noise dict with only chime and vegas pulsars
chime_vegas_noise_dict = {}
for k, v in ng20_noise_real.items():
    new_key = k.replace("t2equad", "equad")
    if "CHIME" in k or "YUPPI" in k or "VEGAS" in k or "J0125-2327" in k or "J0154+1833" in k or "J0614-3329" in k or "J0621+2514" in k or "J0732+2314" in k or "J0751+1807" in k or "J1022+1001" in k or "J1803+1358" in k or "J2022+2534" in k or "J2039-3616" in k or "J2150-0326" in k:
        print(k)
        chime_vegas_noise_dict[new_key] = v

#update nihans noise dict with chime and vegas pulsars from ng20
nihans_noise.update(chime_vegas_noise_dict)
# Out:
# B1855+09_CHIME_efac
# B1855+09_CHIME_log10_ecorr
# B1855+09_CHIME_log10_t2equad
# B1855+09_Rcvr1_2_VEGAS_efac
# B1855+09_Rcvr1_2_VEGAS_log10_ecorr
# B1855+09_Rcvr1_2_VEGAS_log10_t2equad
# B1937+21_3GHz_YUPPI_efac
# B1937+21_3GHz_YUPPI_log10_ecorr
# B1937+21_3GHz_YUPPI_log10_t2equad
# B1937+21_CHIME_efac
# B1937+21_CHIME_log10_ecorr
# B1937+21_CHIME_log10_t2equad
# J1747-4036_Rcvr_800_VEGAS_efac
# J1747-4036_Rcvr_800_VEGAS_log10_ecorr
# J1747-4036_Rcvr_800_VEGAS_log10_t2equad
# J1751-2857_Rcvr1_2_VEGAS_efac
# J1751-2857_Rcvr1_2_VEGAS_log10_ecorr
# J1751-2857_Rcvr1_2_VEGAS_log10_t2equad
# J1751-2857_Rcvr_800_VEGAS_efac
# J1751-2857_Rcvr_800_VEGAS_log10_ecorr
# J1751-2857_Rcvr_800_VEGAS_log10_t2equad
# J1802-2124_3GHz_YUPPI_efac
# J1802-2124_3GHz_YUPPI_log10_ecorr
# J1802-2124_3GHz_YUPPI_log10_t2equad
# J1802-2124_Rcvr1_2_VEGAS_efac
# J1802-2124_Rcvr1_2_VEGAS_log10_ecorr
# J1802-2124_Rcvr1_2_VEGAS_log10_t2equad
# J1802-2124_Rcvr_800_VEGAS_efac
# J1802-2124_Rcvr_800_VEGAS_log10_ecorr
# J1802-2124_Rcvr_800_VEGAS_log10_t2equad
# J1803+1358_CHIME_efac
# J1803+1358_CHIME_log10_ecorr
# J1803+1358_CHIME_log10_t2equad
# J1803+1358_L-wide_PUPPI_efac
# J1803+1358_L-wide_PUPPI_log10_ecorr
# J1803+1358_L-wide_PUPPI_log10_t2equad
# J1803+1358_Rcvr1_2_VEGAS_efac
# J1803+1358_Rcvr1_2_VEGAS_log10_ecorr
# J1803+1358_Rcvr1_2_VEGAS_log10_t2equad
# J1803+1358_red_noise_gamma
# J1803+1358_red_noise_log10_A
# J1811-2405_Rcvr1_2_VEGAS_efac
# J1811-2405_Rcvr1_2_VEGAS_log10_ecorr
# J1811-2405_Rcvr1_2_VEGAS_log10_t2equad
# J1811-2405_Rcvr_800_VEGAS_efac
# J1811-2405_Rcvr_800_VEGAS_log10_ecorr
# J1811-2405_Rcvr_800_VEGAS_log10_t2equad
# J1832-0836_Rcvr1_2_VEGAS_efac
# J1832-0836_Rcvr1_2_VEGAS_log10_ecorr
# J1832-0836_Rcvr1_2_VEGAS_log10_t2equad
# J1832-0836_Rcvr_800_VEGAS_efac
# J1832-0836_Rcvr_800_VEGAS_log10_ecorr
# J1832-0836_Rcvr_800_VEGAS_log10_t2equad
# J1843-1113_Rcvr1_2_VEGAS_efac
# J1843-1113_Rcvr1_2_VEGAS_log10_ecorr
# J1843-1113_Rcvr1_2_VEGAS_log10_t2equad
# J1843-1113_Rcvr_800_VEGAS_efac
# J1843-1113_Rcvr_800_VEGAS_log10_ecorr
# J1843-1113_Rcvr_800_VEGAS_log10_t2equad
# J1853+1303_CHIME_efac
# J1853+1303_CHIME_log10_ecorr
# J1853+1303_CHIME_log10_t2equad
# J1853+1303_Rcvr1_2_VEGAS_efac
# J1853+1303_Rcvr1_2_VEGAS_log10_ecorr
# J1853+1303_Rcvr1_2_VEGAS_log10_t2equad
# J1903+0327_3GHz_YUPPI_efac
# J1903+0327_3GHz_YUPPI_log10_ecorr
# J1903+0327_3GHz_YUPPI_log10_t2equad
# J1903+0327_Rcvr1_2_VEGAS_efac
# J2145-0750_Rcvr_800_VEGAS_log10_ecorr
# J2145-0750_Rcvr_800_VEGAS_log10_t2equad
# J2150-0326_CHIME_efac
# J2150-0326_CHIME_log10_ecorr
# J2150-0326_CHIME_log10_t2equad
# J2150-0326_Rcvr1_2_GUPPI_efac
# J2150-0326_Rcvr1_2_GUPPI_log10_ecorr
# J2150-0326_Rcvr1_2_GUPPI_log10_t2equad
# J2150-0326_Rcvr1_2_VEGAS_efac
# J2150-0326_Rcvr1_2_VEGAS_log10_ecorr
# J2150-0326_Rcvr1_2_VEGAS_log10_t2equad
# J2150-0326_Rcvr_800_GUPPI_efac
# J2150-0326_Rcvr_800_GUPPI_log10_ecorr
# J2150-0326_Rcvr_800_GUPPI_log10_t2equad
# J2150-0326_Rcvr_800_VEGAS_efac
# J2150-0326_Rcvr_800_VEGAS_log10_ecorr
# J2150-0326_Rcvr_800_VEGAS_log10_t2equad
# J2150-0326_red_noise_gamma
# J2150-0326_red_noise_log10_A
# J2214+3000_3GHz_YUPPI_efac
# J2214+3000_3GHz_YUPPI_log10_ecorr
# J2214+3000_3GHz_YUPPI_log10_t2equad
# J2214+3000_CHIME_efac
# J2214+3000_CHIME_log10_ecorr
# J2214+3000_CHIME_log10_t2equad
# J2214+3000_Rcvr1_2_VEGAS_efac
# J2214+3000_Rcvr1_2_VEGAS_log10_ecorr
# J2214+3000_Rcvr1_2_VEGAS_log10_t2equad
# J2229+2643_CHIME_efac
# J2229+2643_CHIME_log10_ecorr
# J2229+2643_CHIME_log10_t2equad
# J2229+2643_Rcvr1_2_VEGAS_efac
# J2229+2643_Rcvr1_2_VEGAS_log10_ecorr
# J2229+2643_Rcvr1_2_VEGAS_log10_t2equad
# J2234+0611_CHIME_efac
# J2234+0611_CHIME_log10_ecorr
# J2234+0611_CHIME_log10_t2equad
# J2234+0611_Rcvr1_2_VEGAS_efac
# J2234+0611_Rcvr1_2_VEGAS_log10_ecorr
# J2234+0611_Rcvr1_2_VEGAS_log10_t2equad
# J2234+0944_CHIME_efac
# J2234+0944_CHIME_log10_ecorr
# J2234+0944_CHIME_log10_t2equad
# J2234+0944_Rcvr1_2_VEGAS_efac
# J2234+0944_Rcvr1_2_VEGAS_log10_ecorr
# J2234+0944_Rcvr1_2_VEGAS_log10_t2equad
# J2302+4442_CHIME_efac
# J2302+4442_CHIME_log10_ecorr
# J2302+4442_CHIME_log10_t2equad
# J2302+4442_Rcvr1_2_VEGAS_efac
# J2302+4442_Rcvr1_2_VEGAS_log10_ecorr
# J2302+4442_Rcvr1_2_VEGAS_log10_t2equad
# J2302+4442_Rcvr_800_VEGAS_efac
# J2302+4442_Rcvr_800_VEGAS_log10_ecorr
# J2302+4442_Rcvr_800_VEGAS_log10_t2equad
# J2317+1439_CHIME_efac
# J2317+1439_CHIME_log10_ecorr
# J2317+1439_CHIME_log10_t2equad
# J2317+1439_Rcvr1_2_VEGAS_efac
# J2317+1439_Rcvr1_2_VEGAS_log10_ecorr
# J2317+1439_Rcvr1_2_VEGAS_log10_t2equad
# J2322+2057_CHIME_efac
# J2322+2057_CHIME_log10_ecorr
# J2322+2057_CHIME_log10_t2equad
# J2322+2057_Rcvr1_2_VEGAS_efac
# J2322+2057_Rcvr1_2_VEGAS_log10_ecorr
# J2322+2057_Rcvr1_2_VEGAS_log10_t2equad

# %%
def make_corr(psr,noise):
    N = psr.toaerrs.size
    corr = np.zeros((N,N))
    _, _, fl, _, bi = hsen.quantize_fast(psr.toas,psr.toaerrs,
                                         flags=psr.flags['f'],dt=1)
    keys = [ky for ky in noise.keys() if psr.name in ky]
    backends = np.unique(psr.flags['f'])
    sigma_sqr = np.zeros(N)
    ecorrs = np.zeros_like(fl,dtype=float)
    for be in backends:
        mask = np.where(psr.flags['f']==be)
        key_ef = '{0}_{1}_{2}'.format(psr.name,be,'efac')
        key_eq = '{0}_{1}_log10_{2}'.format(psr.name,be,'equad')
        key_ec = '{0}_{1}_log10_{2}'.format(psr.name,be,'ecorr')
        sigma_sqr[mask] = (noise[key_ef]**2 * ((psr.toaerrs[mask]**2)
                           + (10**noise[key_eq])**2))#+(10**noise[key_ec])**2)
        mask_ec = np.where(fl==be)
        key_ec = '{0}_{1}_log10_{2}'.format(psr.name,be,'ecorr')
        ecorrs[mask_ec] = np.ones_like(mask_ec) * (10**noise[key_ec])
    j = [ecorrs[ii]**2*np.ones((len(bucket),len(bucket)))
         for ii, bucket in enumerate(bi)]

    J = sl.block_diag(*j)
    corr = np.diag(sigma_sqr) + J
    return corr

# %%
#make correlation matrix with only toaerrs for Sarah's data
def make_corr_our(psr):
    sigma_sqrt = psr.toaerrs**2
    corr = np.diag(sigma_sqrt)
    return corr

# %%
Tspan = hsen.get_Tspan(ePsrs)
fyr = 1/(365.25*24*3600)
freqs = np.logspace(np.log10(1/(5*Tspan)),np.log10(2e-7),600)

# %%
#make hasasia pulsars from enterprise pulsars.
A_gwb, gamma_gwb = 6.4e-15, 3.2 # median values from detection paper
psrs = []
thin = 1
for ePsr in ePsrs:
    corr = make_corr_our(ePsr)[::thin,::thin]
    nihans_corr = make_corr(ePsr,nihans_noise)
    plaw = hsen.red_noise_powerlaw(A=A_gwb, gamma=gamma_gwb, freqs=freqs)
    if ePsr.name in rn_psrs.keys():
        Amp, gam = rn_psrs[ePsr.name]
        plaw += hsen.red_noise_powerlaw(A=10**Amp, gamma=gam, freqs=freqs)

    nihans_corr += hsen.corr_from_psd(freqs=freqs, psd=plaw,
                               toas=ePsr.toas[::thin])
    psr = hsen.Pulsar(toas=ePsr.toas[::thin],
                      toaerrs=ePsr.toaerrs[::thin],
                      phi=ePsr.phi,theta=ePsr.theta,
                      N=nihans_corr, designmatrix=ePsr.Mmat[::thin,:])
    psr.name = ePsr.name
    psrs.append(psr)
    del ePsr
    print('\rPSR {0} complete'.format(psr.name),end='',flush=True)
# Out:
# PSR J2322+2057 complete

# %%
#make spectra
specs = []
for p in psrs:
    sp = hsen.Spectrum(p, freqs=freqs,amp_gw=None, gamma_gw=None)
    _ = sp.NcalInv
    specs.append(sp)
    print('\rPSR {0} complete'.format(p.name),end='',flush=True)
ng20_sarah_nihans_wn = hsen.GWBSensitivityCurve(specs)
# Out:
# PSR J2322+2057 complete

# %%
#plot against original NG15 curve
import matplotlib.pyplot as plt
plt.rcParams["text.usetex"] = False
ng15_pkl_gwb = '/Users/ashokan/osu/sarahspta/ng15yr_v1p1_pint_logf_m2a_red_noise_vg_gwbsc.has' 
with open (ng15_pkl_gwb,'rb') as f:
    ng15_sc_gwb = pickle.load(f)

plt.loglog(ng20_sarah_nihans_wn.freqs,ng20_sarah_nihans_wn.h_c,label='NANOGrav 20-yr with Nihan\'s WN')
plt.loglog(ng15_sc_gwb.freqs,ng15_sc_gwb.h_c,label='NANOGrav 15-yr')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Characteristic Strain, $h_c$')
plt.title('NANOGrav 20v1.1-15-year Data Set Sensitivity Curve')
plt.grid(which='both')
# plt.ylim(1e-15,9e-12)
plt.legend()
plt.show()

# %%
#SNR of full NG20 data now
alpha_gwb = (3. - gamma_gwb) / 2.
S_h = hsen.S_h(A=A_gwb, alpha=alpha_gwb, freqs=freqs)
snr_20 = ng20_sarah_nihans_wn.SNR(S_h)
print(snr_20)
# Out:
# 10.207047213274071

# %% [markdown]
# Okay that is how the full NG20 dataset from Sarah looks like in comparison to NG15. Now lets slice it to 15 year.

# %%
def get_sliced_spectra(psrs, 
                       start_mjd=1,
                       end_mjd = None,
                       ):
    """
    Parameters 
    ----------
    
    psrs : list of enterprise.Pulsar or list of hasasia.Pulsar objects
        List of enterprise/hasasia Pulsar objects
        
    cutoff : float
        MJD cutoff for the calculation
    
    sigma_correction : ?
        ???
    """
    psrs_cut = []
    psrs_copy = copy.deepcopy(psrs)
    for idx, psr in enumerate(psrs_copy):
        # filter the data around to the appropriate slice
        #print("N_toa = ", len(psr.toas))
        psr.filter_data(start_time=start_mjd, end_time=end_mjd)
        #print("after filter = ", len(psr.toas)) 
        # If there are no TOAs remaining, or the time span of the pulsar is <3 cut.
        if (psr.toas.size == 0) or (hsen.get_Tspan([psr]) < 3*365.25*24*3600):
            #idxs.append(idx)
           pass
        else:
            psrs_cut.append(psr)
    timespan = hsen.get_Tspan(psrs_cut)
    spectra = []
    for idx, p in enumerate(psrs_cut):
        sp = hsen.Spectrum(p, freqs=freqs,amp_gw=None, gamma_gw=None)
        sp.name = p.name
        _ = sp.NcalInv
        #print(f"psr spectra {idx} is done")
        spectra.append(sp)
    print(f"PTA spectrum with {len(spectra)} psrs created.")
    return spectra

# %%
end_mjd = 59033
psr_spectra = get_sliced_spectra(psrs, 
                       start_mjd=1,
                       end_mjd = end_mjd,
                       )
# Out:
# PTA spectrum with 67 psrs created.

# %%
#SNR of sliced data
A_gwb, gamma_gwb = 6.4e-15, 3.2
sliced_GWBSC = hsen.GWBSensitivityCurve(spectra=psr_spectra, orf='hd', autocorr=False)
S_h = hsen.S_h(A=A_gwb, alpha=alpha_gwb, freqs=freqs)
sliced_SNR = sliced_GWBSC.SNR(S_h)
print(sliced_SNR)
# Out:
# 6.5192278478159045

# %%
print(len(psrs))
print(len(psr_spectra)) #If there are no TOAs remaining or < 3 years of data pulsar gets left out
# Out:
# 80
# 67

# %%
#plot 15year slice of NG20 against NG15
plt.loglog(sliced_GWBSC.freqs,sliced_GWBSC.h_c,label='15year slice of NANOGrav 20-yr')
plt.loglog(ng15_sc_gwb.freqs,ng15_sc_gwb.h_c,label='NANOGrav 15-yr')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Characteristic Strain, $h_c$')
plt.title(
'NANOGrav Sensitivity Curves, tuned w 15year WN, SNR={:.2f}'.format(
    sliced_SNR
)
)

#plt.title('NANOGrav Sensitivity Curves, tuned with FACTOR={:.4f}'.format(FACTOR),'SNR={:.2f}'.format(sliced_with_factor_SNR))

plt.grid(which='both')
# plt.ylim(1e-15,9e-12)
plt.legend()
plt.show()

# %% [markdown]
# Okay this has an SNR of 6.5
# We want it to be 5 as was in the original NG15 analysis.

# %% [markdown]
# Lets tune its white noise.

# %% [markdown]
# We'll have to use enterprise pulsar objects and chop because hasasia pulsars have no flags etc and their ecorr equad etc become a pain to use in the expression for sigma^2

# %%
#We tune by multiplying toaerrs by a FACTOR
def make_corr_our_tuning_with_all_wn(psr,noise,FACTOR=1.0):
    N = psr.toaerrs.size
    corr = np.zeros((N,N))
    _, _, fl, _, bi = hsen.quantize_fast(psr.toas,psr.toaerrs,
                                         flags=psr.flags['f'],dt=1)
    keys = [ky for ky in noise.keys() if psr.name in ky]
    backends = np.unique(psr.flags['f'])
    sigma_sqr = np.zeros(N)
    ecorrs = np.zeros_like(fl,dtype=float)
    for be in backends:
        mask = np.where(psr.flags['f']==be)
        key_ef = '{0}_{1}_{2}'.format(psr.name,be,'efac')
        key_eq = '{0}_{1}_log10_{2}'.format(psr.name,be,'equad')
        key_ec = '{0}_{1}_log10_{2}'.format(psr.name,be,'ecorr')
        sigma_sqr[mask] = (noise[key_ef]**2 * (FACTOR*(psr.toaerrs[mask]**2)
                           + (10**noise[key_eq])**2))#+(10**noise[key_ec])**2)
        mask_ec = np.where(fl==be)
        key_ec = '{0}_{1}_log10_{2}'.format(psr.name,be,'ecorr')
        ecorrs[mask_ec] = np.ones_like(mask_ec) * (10**noise[key_ec])
    j = [ecorrs[ii]**2*np.ones((len(bucket),len(bucket)))
         for ii, bucket in enumerate(bi)]

    J = sl.block_diag(*j)
    corr = np.diag(sigma_sqr) + J
    return corr

# %% [markdown]
# Lets try to chop enterprise pulsars instead of hasasia pulsars.

# %%
def get_sliced_epulsars(psrs, 
                       start_mjd=1,
                       end_mjd = None,
                       ):
    """
    Parameters 
    ----------
    
    psrs : list of enterprise.Pulsar or list of hasasia.Pulsar objects
        List of enterprise/hasasia Pulsar objects

    start_mjd : float
        MJD start time for the calculation

    end_mjd : float
        MJD end time for the calculation
    """
    psrs_cut = []
    psrs_copy = copy.deepcopy(psrs)
    for idx, psr in enumerate(psrs_copy):
        # filter the data around to the appropriate slice
        #print("N_toa = ", len(psr.toas))
        psr.filter_data(start_time=start_mjd, end_time=end_mjd)
        #print("after filter = ", len(psr.toas)) 
        # If there are no TOAs remaining, or the time span of the pulsar is <3 cut.
        if (psr.toas.size == 0) or (hsen.get_Tspan([psr]) < 3*365.25*24*3600):
    #         idxs.append(idx)
            pass
        else:
            psrs_cut.append(psr)
    return psrs_cut

# %%
end_mjd = 59033
epsrs_cut_NG15 = get_sliced_epulsars(ePsrs, 
                       start_mjd=1,
                       end_mjd = end_mjd,
                       )

# %%
print(len(ePsrs))
print(len(epsrs_cut_NG15)) #once again if no TOAs or < 3 years of data pulsar gets left out
# Out:
# 80
# 67

# %% [markdown]
# ## Loop over prefactors

# %%
sliced_15yr_SNRS = []
for prefactor in [0.98,0.985,0.99,1,2]:
    FACTOR = prefactor*1.45*np.sqrt(np.pi)
    print("FACTOR = ", FACTOR)    
    A_gwb, gamma_gwb = 6.4e-15, 3.2 # median values from detection paper
    psrs = []
    thin = 1
    for ePsr in epsrs_cut_NG15:
        nihans_corr = make_corr_our_tuning_with_all_wn(ePsr,nihans_noise,FACTOR=FACTOR)
        plaw = hsen.red_noise_powerlaw(A=A_gwb, gamma=gamma_gwb, freqs=freqs)
        if ePsr.name in rn_psrs.keys():
            Amp, gam = rn_psrs[ePsr.name]
            plaw += hsen.red_noise_powerlaw(A=10**Amp, gamma=gam, freqs=freqs)

        nihans_corr += hsen.corr_from_psd(freqs=freqs, psd=plaw,
                                toas=ePsr.toas[::thin])
        psr = hsen.Pulsar(toas=ePsr.toas[::thin],
                        toaerrs=ePsr.toaerrs[::thin],
                        phi=ePsr.phi,theta=ePsr.theta,
                        N=nihans_corr, designmatrix=ePsr.Mmat[::thin,:])
        psr.name = ePsr.name
        psrs.append(psr)
        del ePsr
    print('\rPSR {0} complete'.format(psr.name),end='',flush=True)

    specs = []
    for p in psrs:
        sp = hsen.Spectrum(p, freqs=freqs,amp_gw=None, gamma_gw=None)
        _ = sp.NcalInv
        specs.append(sp)
        #print('\rPSR {0} complete'.format(p.name),end='',flush=True)

    ng20_sarah_sc_with_factor = hsen.GWBSensitivityCurve(specs)
    sliced_with_factor_SNR = ng20_sarah_sc_with_factor.SNR(S_h)
    sliced_15yr_SNRS.append(sliced_with_factor_SNR)
    print("sliced_with_factor_SNR = ", sliced_with_factor_SNR)

    plt.loglog(ng20_sarah_sc_with_factor.freqs,ng20_sarah_sc_with_factor.h_c,label='15year slice of NANOGrav 20-yr')
    plt.loglog(ng15_sc_gwb.freqs,ng15_sc_gwb.h_c,label='NANOGrav 15-yr')
    plt.xlabel('Frequency [Hz]')
    plt.ylabel('Characteristic Strain, $h_c$')
    plt.title(
    'NANOGrav Sensitivity Curves, tuned with FACTOR={:.4f}, SNR={:.2f}'.format(
        FACTOR, sliced_with_factor_SNR
    )
)
    #plt.title('NANOGrav 20-15-year Data Set Sensitivity Curve, tuned with FACTOR={0}'.format(FACTOR))
    plt.grid(which='both')
    # plt.ylim(1e-15,9e-12)
    plt.legend()
    plt.show()
# Out:
# FACTOR =  2.518656922136738
# PSR J2322+2057 completesliced_with_factor_SNR =  5.008697545082477
# FACTOR =  2.531507212555803
# PSR J2322+2057 completesliced_with_factor_SNR =  5.00128612258093
# FACTOR =  2.544357502974868
# PSR J2322+2057 completesliced_with_factor_SNR =  4.99391353770245
# FACTOR =  2.570058083812998
# PSR J2322+2057 completesliced_with_factor_SNR =  4.9792833718087
# FACTOR =  5.140116167625996
# PSR J2322+2057 completesliced_with_factor_SNR =  3.991488557796869

# %% [markdown]
# The last one is just to show that the sensitivity curve is being affected by the factor although it might not seem like it with the first three values of factor!

# %% [markdown]
# ### So to conclude, if you use a factor of 2.544357502974868 on toaerror, and use the noise dict formed by the combination of 15year WN + (CHIME, VEGAS, extra pulsars) from real NG20, then you will get an SNR of 4.99 on the NG15 slice of the simulated NG20 dataset.

# %%
#FACTOR = prefactor*1.45*np.sqrt(np.pi)
sliced_15yr_SNRS = []
FACTOR  = 2.54
print("FACTOR = ", FACTOR)    
A_gwb, gamma_gwb = 6.4e-15, 3.2 # median values from detection paper
psrs = []
thin = 1
for ePsr in epsrs_cut_NG15:
    nihans_corr = make_corr_our_tuning_with_all_wn(ePsr,nihans_noise,FACTOR=FACTOR)
    plaw = hsen.red_noise_powerlaw(A=A_gwb, gamma=gamma_gwb, freqs=freqs)
    if ePsr.name in rn_psrs.keys():
        Amp, gam = rn_psrs[ePsr.name]
        plaw += hsen.red_noise_powerlaw(A=10**Amp, gamma=gam, freqs=freqs)

    nihans_corr += hsen.corr_from_psd(freqs=freqs, psd=plaw,
                            toas=ePsr.toas[::thin])
    psr = hsen.Pulsar(toas=ePsr.toas[::thin],
                    toaerrs=ePsr.toaerrs[::thin],
                    phi=ePsr.phi,theta=ePsr.theta,
                    N=nihans_corr, designmatrix=ePsr.Mmat[::thin,:])
    psr.name = ePsr.name
    psrs.append(psr)
    del ePsr
print('\rPSR {0} complete'.format(psr.name),end='',flush=True)

specs = []
for p in psrs:
    sp = hsen.Spectrum(p, freqs=freqs,amp_gw=None, gamma_gw=None)
    _ = sp.NcalInv
    specs.append(sp)
    #print('\rPSR {0} complete'.format(p.name),end='',flush=True)

ng20_sarah_sc_with_factor = hsen.GWBSensitivityCurve(specs)
sliced_with_factor_SNR = ng20_sarah_sc_with_factor.SNR(S_h)
sliced_15yr_SNRS.append(sliced_with_factor_SNR)
print("sliced_with_factor_SNR = ", sliced_with_factor_SNR)

plt.loglog(ng20_sarah_sc_with_factor.freqs,ng20_sarah_sc_with_factor.h_c,label='15year slice of NANOGrav 20-yr')
plt.loglog(ng15_sc_gwb.freqs,ng15_sc_gwb.h_c,label='NANOGrav 15-yr')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Characteristic Strain, $h_c$')
plt.title(
'NANOGrav Sensitivity Curves, tuned with FACTOR={:.4f}, SNR={:.2f}'.format(
    FACTOR, sliced_with_factor_SNR
)
)
#plt.title('NANOGrav 20-15-year Data Set Sensitivity Curve, tuned with FACTOR={0}'.format(FACTOR))
plt.grid(which='both')
# plt.ylim(1e-15,9e-12)
plt.legend()
plt.show()
# Out:
# FACTOR =  2.54
# PSR J2322+2057 completesliced_with_factor_SNR =  4.996409156873098
